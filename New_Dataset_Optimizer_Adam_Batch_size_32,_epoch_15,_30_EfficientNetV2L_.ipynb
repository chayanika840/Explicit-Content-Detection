# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## **Importing necessary packages**

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import cv2
import os
import warnings
warnings.filterwarnings('ignore')

from sklearn.metrics import confusion_matrix, classification_report

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation, BatchNormalization, Conv2D, Dense, Dropout, Flatten, MaxPool2D,MaxPooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping

# %% [markdown]
# ## **2. Load the Image Training and Validation Datasets**
#
# ### i. Get the Image Dataset Paths

# %%
train_dataset_path = '/content/drive/MyDrive/FYP/train'
validation_dataset_path = '/content/drive/MyDrive/FYP/val'

# %% [markdown]
# ### ii. Load Image Datasets and Apply Augmentations
# Since the images present in the datasets are 150x150px in size, the image height and width are taken as 150, 150 respectively. The batch size value can be changed if required.

# %%
IMG_WIDTH = 150
IMG_HEIGHT = 150
BATCH_SIZE = 32

# %% [markdown]
# Loading the training dataset and applying augmentations on it.

# %%
train_datagen = ImageDataGenerator(rescale=1.0/255,
                                  zoom_range=0.2,
                                  width_shift_range=0.2,
                                  height_shift_range=0.2,
                                  fill_mode='nearest')
train_generator = train_datagen.flow_from_directory(train_dataset_path,
                                                   target_size=(IMG_WIDTH, IMG_HEIGHT),
                                                   batch_size=BATCH_SIZE,
                                                   class_mode='categorical',
                                                   shuffle=True)
# Out:
# Found 3009 images belonging to 2 classes.

# %% [markdown]
# Loading the validation dataset.

# %%
validation_datagen = ImageDataGenerator(rescale=1.0/255)
validation_generator = validation_datagen.flow_from_directory(validation_dataset_path,
                                                             target_size=(IMG_WIDTH, IMG_HEIGHT),
                                                             batch_size=BATCH_SIZE,
                                                             class_mode='categorical',
                                                             shuffle=True)
# Out:
# Found 3019 images belonging to 2 classes.

# %% [markdown]
# ### iii. Get the Label Mappings
# The labels dictionary is made in order to retrive the class names against the label indices used for training the model

# %%
labels = {value: key for key, value in train_generator.class_indices.items()}

print("Label Mappings for classes present in the training and validation datasets\n")
for key, value in labels.items():
    print(f"{key} : {value}")
# Out:
# Label Mappings for classes present in the training and validation datasets
#
# 0 : Nonnude
# 1 : Nude

# %% [markdown]
# ## **3. Plotting Sample Training Image**s

# %%
fig, ax = plt.subplots(nrows=2, ncols=5, figsize=(15, 12))
idx = 0

for i in range(2):
    for j in range(5):
        label = labels[np.argmax(train_generator[0][1][idx])]
        ax[i, j].set_title(f"{label}")
        ax[i, j].imshow(train_generator[0][0][idx][:, :, :])
        ax[i, j].axis("off")
        idx += 1

plt.tight_layout()
plt.suptitle("Sample Training Images", fontsize=21)
plt.show()

# %% [markdown]
# ## **4. Training a InceptionResNetV2 Model**
#
#
# ### i. Create a InceptionResNetV2 Model

# %%
base_model = tf.keras.applications.EfficientNetV2L(
                     include_top=False,
                     weights='imagenet',
                     input_shape=(150,150,3),
                     include_preprocessing=True

                     )

base_model.trainable=True
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/efficientnet_v2/efficientnetv2-l_notop.h5
# 473176280/473176280 [==============================] - 3s 0us/step

# %%
model = tf.keras.Sequential([
        base_model,  
        tf.keras.layers.BatchNormalization(renorm=True),
        tf.keras.layers.GlobalAveragePooling2D(),
        tf.keras.layers.Dense(512, activation='relu'),
        tf.keras.layers.Dense(256, activation='relu'),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.Dense(128, activation='relu'),
        tf.keras.layers.Dense(2, activation='softmax')
    ])

# %%
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  efficientnetv2-l (Functiona  (None, 5, 5, 1280)       117746848
#  l)
#
#  batch_normalization (BatchN  (None, 5, 5, 1280)       8960
#  ormalization)
#
#  global_average_pooling2d (G  (None, 1280)             0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 512)               655872
#
#  dense_1 (Dense)             (None, 256)               131328
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_2 (Dense)             (None, 128)               32896
#
#  dense_3 (Dense)             (None, 2)                 258
#
# =================================================================
# Total params: 118,576,162
# Trainable params: 118,057,186
# Non-trainable params: 518,976
# _________________________________________________________________
# None

# %% [markdown]
# ### ii. Defining Callbacks
# A callback is an object that can perform actions at various stages of training (e.g. at the start or end of an epoch, before or after a single batch, etc)
#
# a. Reduce Learning Rate on Plateau
# Is used to reduce the learning rate when a metric has stopped improving.

# %%
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=np.sqrt(0.1), patience=5)
early = tf.keras.callbacks.EarlyStopping( patience=10,
                                          min_delta=0.001,
                                          restore_best_weights=True)

# %%
# !pip install tensorflow_addons
import tensorflow_addons as tfa
METRICS = [
      # tf.keras.metrics.BinaryAccuracy(name='binary_accuracy'),
      # tf.keras.metrics.Accuracy(name='accuracy'),
      tf.keras.metrics.CategoricalAccuracy(name='accuracy'),
      tf.keras.metrics.Precision(name='precision'),
      tf.keras.metrics.Recall(name='recall'),  
      tf.keras.metrics.AUC(name='auc'),
      # tf.keras.metrics.F1Score(name='F1'),
      tfa.metrics.F1Score(num_classes= 2,name="f1_Score")

    
]
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tensorflow_addons
#   Downloading tensorflow_addons-0.19.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 17.3 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from tensorflow_addons) (23.0)
# Collecting typeguard>=2.7
#   Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Installing collected packages: typeguard, tensorflow_addons
# Successfully installed tensorflow_addons-0.19.0 typeguard-2.13.3

# %% [markdown]
# ### iii. Defining the Optimizer

# %%
optimizer = Adam(learning_rate=0.001)
sgd = SGD(lr=0.001)
# Out:
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.SGD.

# %% [markdown]
# ### iv. Compile the Model

# %%
# cnn_model.compile(optimizer=optimizer, loss=CategoricalCrossentropy(), metrics=['accuracy'])
model.compile(optimizer=optimizer,loss='categorical_crossentropy',metrics=METRICS)

# %% [markdown]
# ### v. Training the Model

# %%
history = model.fit(train_generator,
                    steps_per_epoch=15,
                    validation_data=validation_generator,
                    validation_steps=2,
                    epochs=30,verbose = 2,
                    callbacks=[reduce_lr])
# Out:
# Epoch 1/30
# WARNING:tensorflow:From /usr/local/lib/python3.9/dist-packages/tensorflow/python/autograph/pyct/static_analysis/liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089
# 15/15 - 289s - loss: 0.5130 - accuracy: 0.7792 - precision: 0.7792 - recall: 0.7792 - auc: 0.8695 - f1_Score: 0.7790 - val_loss: 4.7091 - val_accuracy: 0.5156 - val_precision: 0.5156 - val_recall: 0.5156 - val_auc: 0.5156 - val_f1_Score: 0.3402 - lr: 0.0010 - 289s/epoch - 19s/step
# Epoch 2/30
# 15/15 - 78s - loss: 0.4872 - accuracy: 0.8104 - precision: 0.8104 - recall: 0.8104 - auc: 0.8923 - f1_Score: 0.8096 - val_loss: 3.9149 - val_accuracy: 0.5156 - val_precision: 0.5156 - val_recall: 0.5156 - val_auc: 0.5164 - val_f1_Score: 0.4108 - lr: 0.0010 - 78s/epoch - 5s/step
# Epoch 3/30
# 15/15 - 74s - loss: 0.4600 - accuracy: 0.8104 - precision: 0.8104 - recall: 0.8104 - auc: 0.8745 - f1_Score: 0.8084 - val_loss: 0.8477 - val_accuracy: 0.5156 - val_precision: 0.5156 - val_recall: 0.5156 - val_auc: 0.5208 - val_f1_Score: 0.4875 - lr: 0.0010 - 74s/epoch - 5s/step
# Epoch 4/30
# 15/15 - 59s - loss: 0.3353 - accuracy: 0.8664 - precision: 0.8664 - recall: 0.8664 - auc: 0.9349 - f1_Score: 0.8664 - val_loss: 0.7826 - val_accuracy: 0.5781 - val_precision: 0.5781 - val_recall: 0.5781 - val_auc: 0.6113 - val_f1_Score: 0.3663 - lr: 0.0010 - 59s/epoch - 4s/step
# Epoch 5/30
# 15/15 - 54s - loss: 0.3910 - accuracy: 0.8438 - precision: 0.8438 - recall: 0.8438 - auc: 0.9153 - f1_Score: 0.8437 - val_loss: 0.6577 - val_accuracy: 0.5312 - val_precision: 0.5312 - val_recall: 0.5312 - val_auc: 0.6423 - val_f1_Score: 0.5195 - lr: 0.0010 - 54s/epoch - 4s/step
# Epoch 6/30
# 15/15 - 55s - loss: 0.2434 - accuracy: 0.9208 - precision: 0.9208 - recall: 0.9208 - auc: 0.9624 - f1_Score: 0.9207 - val_loss: 0.3412 - val_accuracy: 0.8594 - val_precision: 0.8594 - val_recall: 0.8594 - val_auc: 0.9294 - val_f1_Score: 0.8533 - lr: 0.0010 - 55s/epoch - 4s/step
# Epoch 7/30
# 15/15 - 48s - loss: 0.2998 - accuracy: 0.8750 - precision: 0.8750 - recall: 0.8750 - auc: 0.9472 - f1_Score: 0.8750 - val_loss: 1.4627 - val_accuracy: 0.5312 - val_precision: 0.5312 - val_recall: 0.5312 - val_auc: 0.6069 - val_f1_Score: 0.3469 - lr: 0.0010 - 48s/epoch - 3s/step
# Epoch 8/30
# 15/15 - 48s - loss: 0.2996 - accuracy: 0.8979 - precision: 0.8979 - recall: 0.8979 - auc: 0.9517 - f1_Score: 0.8979 - val_loss: 1.4888 - val_accuracy: 0.4844 - val_precision: 0.4844 - val_recall: 0.4844 - val_auc: 0.6021 - val_f1_Score: 0.3263 - lr: 0.0010 - 48s/epoch - 3s/step
# Epoch 9/30
# 15/15 - 41s - loss: 0.2871 - accuracy: 0.8729 - precision: 0.8729 - recall: 0.8729 - auc: 0.9510 - f1_Score: 0.8726 - val_loss: 2.2590 - val_accuracy: 0.4844 - val_precision: 0.4844 - val_recall: 0.4844 - val_auc: 0.5920 - val_f1_Score: 0.3263 - lr: 0.0010 - 41s/epoch - 3s/step
# Epoch 10/30
# 15/15 - 39s - loss: 0.3466 - accuracy: 0.8604 - precision: 0.8604 - recall: 0.8604 - auc: 0.9336 - f1_Score: 0.8600 - val_loss: 1.6123 - val_accuracy: 0.4688 - val_precision: 0.4688 - val_recall: 0.4688 - val_auc: 0.5891 - val_f1_Score: 0.3191 - lr: 0.0010 - 39s/epoch - 3s/step
# Epoch 11/30
# 15/15 - 36s - loss: 0.2966 - accuracy: 0.8797 - precision: 0.8797 - recall: 0.8797 - auc: 0.9498 - f1_Score: 0.8797 - val_loss: 2.7107 - val_accuracy: 0.3438 - val_precision: 0.3438 - val_recall: 0.3438 - val_auc: 0.4932 - val_f1_Score: 0.2558 - lr: 0.0010 - 36s/epoch - 2s/step
# Epoch 12/30
# 15/15 - 32s - loss: 0.2653 - accuracy: 0.9000 - precision: 0.9000 - recall: 0.9000 - auc: 0.9579 - f1_Score: 0.8997 - val_loss: 0.4217 - val_accuracy: 0.8281 - val_precision: 0.8281 - val_recall: 0.8281 - val_auc: 0.9146 - val_f1_Score: 0.8260 - lr: 3.1623e-04 - 32s/epoch - 2s/step
# Epoch 13/30
# 15/15 - 31s - loss: 0.1629 - accuracy: 0.9399 - precision: 0.9399 - recall: 0.9399 - auc: 0.9865 - f1_Score: 0.9397 - val_loss: 0.9450 - val_accuracy: 0.5312 - val_precision: 0.5312 - val_recall: 0.5312 - val_auc: 0.5945 - val_f1_Score: 0.5000 - lr: 3.1623e-04 - 31s/epoch - 2s/step
# Epoch 14/30
# 15/15 - 32s - loss: 0.1542 - accuracy: 0.9312 - precision: 0.9312 - recall: 0.9312 - auc: 0.9842 - f1_Score: 0.9311 - val_loss: 0.8330 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.6687 - val_f1_Score: 0.3333 - lr: 3.1623e-04 - 32s/epoch - 2s/step
# Epoch 15/30
# 15/15 - 36s - loss: 0.1583 - accuracy: 0.9376 - precision: 0.9376 - recall: 0.9376 - auc: 0.9837 - f1_Score: 0.9376 - val_loss: 0.5068 - val_accuracy: 0.6875 - val_precision: 0.6875 - val_recall: 0.6875 - val_auc: 0.8091 - val_f1_Score: 0.6847 - lr: 3.1623e-04 - 36s/epoch - 2s/step
# Epoch 16/30
# 15/15 - 31s - loss: 0.1811 - accuracy: 0.9333 - precision: 0.9333 - recall: 0.9333 - auc: 0.9814 - f1_Score: 0.9329 - val_loss: 0.3810 - val_accuracy: 0.8125 - val_precision: 0.8125 - val_recall: 0.8125 - val_auc: 0.9297 - val_f1_Score: 0.8078 - lr: 3.1623e-04 - 31s/epoch - 2s/step
# Epoch 17/30
# 15/15 - 31s - loss: 0.1451 - accuracy: 0.9458 - precision: 0.9458 - recall: 0.9458 - auc: 0.9877 - f1_Score: 0.9458 - val_loss: 0.5526 - val_accuracy: 0.7344 - val_precision: 0.7344 - val_recall: 0.7344 - val_auc: 0.8759 - val_f1_Score: 0.7290 - lr: 1.0000e-04 - 31s/epoch - 2s/step
# Epoch 18/30
# 15/15 - 29s - loss: 0.1118 - accuracy: 0.9521 - precision: 0.9521 - recall: 0.9521 - auc: 0.9924 - f1_Score: 0.9521 - val_loss: 0.5399 - val_accuracy: 0.8125 - val_precision: 0.8125 - val_recall: 0.8125 - val_auc: 0.9182 - val_f1_Score: 0.8031 - lr: 1.0000e-04 - 29s/epoch - 2s/step
# Epoch 19/30
# 15/15 - 27s - loss: 0.1011 - accuracy: 0.9688 - precision: 0.9688 - recall: 0.9688 - auc: 0.9931 - f1_Score: 0.9686 - val_loss: 0.5798 - val_accuracy: 0.8125 - val_precision: 0.8125 - val_recall: 0.8125 - val_auc: 0.8750 - val_f1_Score: 0.8095 - lr: 1.0000e-04 - 27s/epoch - 2s/step
# Epoch 20/30
# 15/15 - 28s - loss: 0.0807 - accuracy: 0.9750 - precision: 0.9750 - recall: 0.9750 - auc: 0.9957 - f1_Score: 0.9750 - val_loss: 0.3573 - val_accuracy: 0.8281 - val_precision: 0.8281 - val_recall: 0.8281 - val_auc: 0.9404 - val_f1_Score: 0.8260 - lr: 1.0000e-04 - 28s/epoch - 2s/step
# Epoch 21/30
# 15/15 - 27s - loss: 0.1257 - accuracy: 0.9542 - precision: 0.9542 - recall: 0.9542 - auc: 0.9897 - f1_Score: 0.9541 - val_loss: 0.2289 - val_accuracy: 0.8594 - val_precision: 0.8594 - val_recall: 0.8594 - val_auc: 0.9705 - val_f1_Score: 0.8593 - lr: 1.0000e-04 - 27s/epoch - 2s/step
# Epoch 22/30
# 15/15 - 27s - loss: 0.0885 - accuracy: 0.9583 - precision: 0.9583 - recall: 0.9583 - auc: 0.9956 - f1_Score: 0.9582 - val_loss: 0.3626 - val_accuracy: 0.8438 - val_precision: 0.8438 - val_recall: 0.8438 - val_auc: 0.9617 - val_f1_Score: 0.8303 - lr: 1.0000e-04 - 27s/epoch - 2s/step
# Epoch 23/30
# 15/15 - 26s - loss: 0.0821 - accuracy: 0.9688 - precision: 0.9688 - recall: 0.9688 - auc: 0.9943 - f1_Score: 0.9687 - val_loss: 0.0946 - val_accuracy: 0.9688 - val_precision: 0.9688 - val_recall: 0.9688 - val_auc: 0.9946 - val_f1_Score: 0.9686 - lr: 1.0000e-04 - 26s/epoch - 2s/step
# Epoch 24/30
# 15/15 - 24s - loss: 0.0962 - accuracy: 0.9583 - precision: 0.9583 - recall: 0.9583 - auc: 0.9929 - f1_Score: 0.9583 - val_loss: 0.0883 - val_accuracy: 0.9531 - val_precision: 0.9531 - val_recall: 0.9531 - val_auc: 0.9954 - val_f1_Score: 0.9504 - lr: 1.0000e-04 - 24s/epoch - 2s/step
# Epoch 25/30
# 15/15 - 25s - loss: 0.0824 - accuracy: 0.9708 - precision: 0.9708 - recall: 0.9708 - auc: 0.9959 - f1_Score: 0.9708 - val_loss: 0.3533 - val_accuracy: 0.8750 - val_precision: 0.8750 - val_recall: 0.8750 - val_auc: 0.9504 - val_f1_Score: 0.8730 - lr: 1.0000e-04 - 25s/epoch - 2s/step
# Epoch 26/30
# 15/15 - 26s - loss: 0.0754 - accuracy: 0.9604 - precision: 0.9604 - recall: 0.9604 - auc: 0.9970 - f1_Score: 0.9604 - val_loss: 0.3981 - val_accuracy: 0.8594 - val_precision: 0.8594 - val_recall: 0.8594 - val_auc: 0.9270 - val_f1_Score: 0.8533 - lr: 1.0000e-04 - 26s/epoch - 2s/step
# Epoch 27/30
# 15/15 - 25s - loss: 0.0907 - accuracy: 0.9604 - precision: 0.9604 - recall: 0.9604 - auc: 0.9953 - f1_Score: 0.9604 - val_loss: 0.2821 - val_accuracy: 0.8906 - val_precision: 0.8906 - val_recall: 0.8906 - val_auc: 0.9568 - val_f1_Score: 0.8900 - lr: 1.0000e-04 - 25s/epoch - 2s/step
# Epoch 28/30
# 15/15 - 22s - loss: 0.0968 - accuracy: 0.9733 - precision: 0.9733 - recall: 0.9733 - auc: 0.9932 - f1_Score: 0.9733 - val_loss: 0.3370 - val_accuracy: 0.8594 - val_precision: 0.8594 - val_recall: 0.8594 - val_auc: 0.9519 - val_f1_Score: 0.8512 - lr: 1.0000e-04 - 22s/epoch - 1s/step
# Epoch 29/30
# 15/15 - 24s - loss: 0.0682 - accuracy: 0.9771 - precision: 0.9771 - recall: 0.9771 - auc: 0.9973 - f1_Score: 0.9771 - val_loss: 0.2057 - val_accuracy: 0.8750 - val_precision: 0.8750 - val_recall: 0.8750 - val_auc: 0.9717 - val_f1_Score: 0.8745 - lr: 1.0000e-04 - 24s/epoch - 2s/step
# Epoch 30/30
# 15/15 - 22s - loss: 0.0598 - accuracy: 0.9792 - precision: 0.9792 - recall: 0.9792 - auc: 0.9980 - f1_Score: 0.9792 - val_loss: 0.0635 - val_accuracy: 0.9531 - val_precision: 0.9531 - val_recall: 0.9531 - val_auc: 0.9978 - val_f1_Score: 0.9526 - lr: 3.1623e-05 - 22s/epoch - 1s/step

# %% [markdown]
# ## **5. Plotting the Model Metrics**
# ### i. Plotting training and validation accuracy, loss and learning rate

# %%
plt.figure( figsize = (15,8)) 
    
plt.subplot(221)  
# Accuracy 
plt.plot(model.history.history['accuracy'])
plt.plot(model.history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Training set', 'Validation set'], loc='upper left')
plt.show()


# Loss
plt.figure( figsize = (15,8)) 
plt.subplot(222)  
plt.plot(model.history.history['loss'])
plt.plot(model.history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Training set', 'Validation set'], loc='upper left')
plt.show()

# %%
train_accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

train_loss = history.history['loss']
val_loss = history.history['val_loss']

learning_rate = history.history['lr']


ans = history.history['val_recall']
ans
# Out:
# [0.515625,
#  0.515625,
#  0.515625,
#  0.578125,
#  0.53125,
#  0.859375,
#  0.53125,
#  0.484375,
#  0.484375,
#  0.46875,
#  0.34375,
#  0.828125,
#  0.53125,
#  0.5,
#  0.6875,
#  0.8125,
#  0.734375,
#  0.8125,
#  0.8125,
#  0.828125,
#  0.859375,
#  0.84375,
#  0.96875,
#  0.953125,
#  0.875,
#  0.859375,
#  0.890625,
#  0.859375,
#  0.875,
#  0.953125]

# %%
fig, ax = plt.subplots(nrows=3, ncols=1, figsize=(12, 10))

ax[0].set_title('Training Accuracy vs. Epochs')
ax[0].plot(train_accuracy, 'o-', label='Train Accuracy')
ax[0].plot(val_accuracy, 'o-', label='Validation Accuracy')
ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Accuracy')
ax[0].legend(loc='best')

ax[1].set_title('Training/Validation Loss vs. Epochs')
ax[1].plot(train_loss, 'o-', label='Train Loss')
ax[1].plot(val_loss, 'o-', label='Validation Loss')
ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Loss')
ax[1].legend(loc='best')

ax[2].set_title('Learning Rate vs. Epochs')
ax[2].plot(learning_rate, 'o-', label='Learning Rate')
ax[2].set_xlabel('Epochs')
ax[2].set_ylabel('Loss')
ax[2].legend(loc='best')

plt.tight_layout()
plt.show()

# %%
def Train_Val_Plot(acc,val_acc,loss,val_loss,auc,val_auc,precision,val_precision,f1_Score,val_f1_Score):
    
    fig, (ax1, ax2,ax3,ax4,ax5) = plt.subplots(1,5, figsize= (20,5))
    fig.suptitle(" MODEL'S METRICS VISUALIZATION ")

    ax1.plot(range(1, len(acc) + 1), acc)
    ax1.plot(range(1, len(val_acc) + 1), val_acc)
    ax1.set_title('History of Accuracy')
    ax1.set_xlabel('Epochs')
    ax1.set_ylabel('Accuracy')
    ax1.legend(['training', 'validation'])


    ax2.plot(range(1, len(loss) + 1), loss)
    ax2.plot(range(1, len(val_loss) + 1), val_loss)
    ax2.set_title('History of Loss')
    ax2.set_xlabel('Epochs')
    ax2.set_ylabel('Loss')
    ax2.legend(['training', 'validation'])
    
    ax3.plot(range(1, len(auc) + 1), auc)
    ax3.plot(range(1, len(val_auc) + 1), val_auc)
    ax3.set_title('History of AUC')
    ax3.set_xlabel('Epochs')
    ax3.set_ylabel('AUC')
    ax3.legend(['training', 'validation'])
    
    ax4.plot(range(1, len(precision) + 1), precision)
    ax4.plot(range(1, len(val_precision) + 1), val_precision)
    ax4.set_title('History of Precision')
    ax4.set_xlabel('Epochs')
    ax4.set_ylabel('Precision')
    ax4.legend(['training', 'validation'])
    
    ax5.plot(range(1, len(f1_Score) + 1), f1_Score)
    ax5.plot(range(1, len(val_f1_Score) + 1), val_f1_Score)
    ax5.set_title('History of F1-score')
    ax5.set_xlabel('Epochs')
    ax5.set_ylabel('F1 score')
    ax5.legend(['training', 'validation'])


    plt.show()
    
import numpy as np
# f1_s= np.mean(history.history['f1_Score'])
# val_f1_s= np.mean(history.history['val_f1_Score'])
Train_Val_Plot(history.history['accuracy'],history.history['val_accuracy'],
               history.history['loss'],history.history['val_loss'],
               history.history['auc'],history.history['val_auc'],
               history.history['precision'],history.history['val_precision']
              #  f1_s,val_f1_s

                , history.history['f1_Score'],history.history['val_f1_Score']
              )

# %% [markdown]
# ## 6. Testing the Model on Test Set
# Testing the model on the validation dataset because a seperate dataset for testing is not available.

# %%
test_dataset = '/content/drive/MyDrive/FYP/test'

# %%
test_datagen = ImageDataGenerator(rescale=1.0/255)

test_generator = test_datagen.flow_from_directory(test_dataset,
                                                 shuffle=False,
                                                 batch_size=BATCH_SIZE,
                                                 target_size = (IMG_WIDTH, IMG_HEIGHT),
                                                 class_mode='categorical')
# Out:
# Found 3000 images belonging to 2 classes.

# %% [markdown]
# ## 7. Model Prediction on the Test Dataset

# %%
predictions = model.predict(test_generator)
# Out:
# 94/94 [==============================] - 345s 4s/step

# %%
fig, ax = plt.subplots(nrows=2, ncols=5, figsize=(12, 10))
idx = 0

for i in range(2):
    for j in range(5):
        predicted_label = labels[np.argmax(predictions[idx])]
        ax[i, j].set_title(f"{predicted_label}")
        ax[i, j].imshow(test_generator[0][0][idx])
        ax[i, j].axis("off")
        idx += 1

plt.tight_layout()
plt.suptitle("Test Dataset Predictions", fontsize=20)
plt.show()

# %%
train_loss, train_accuracy, train_precision, train_recall, train_auc, train_F1_Score = model.evaluate(train_generator, batch_size=BATCH_SIZE)
# Out:
# 95/95 [==============================] - 53s 550ms/step - loss: 0.0368 - accuracy: 0.9884 - precision: 0.9884 - recall: 0.9884 - auc: 0.9989 - f1_Score: 0.9884

# %%
print(f"Train Loss:     {train_loss}")
print(f"Train Accuracy: {train_accuracy}")
print(f"Train Precision: {train_precision}")
print(f"Train Recall: {train_recall}")
print(f"Train AUC: {train_auc}")
print(f"Train F1_Score: {np.mean(train_F1_Score)}")
# Out:
# Train Loss:     0.036811426281929016
# Train Accuracy: 0.9883682131767273
# Train Precision: 0.9883682131767273
# Train Recall: 0.9883682131767273
# Train AUC: 0.9989415407180786
# Train F1_Score: 0.9883681535720825

# %%
test_loss, test_accuracy, test_precision, test_recall, test_auc, test_F1_Score = model.evaluate(test_generator, batch_size=BATCH_SIZE)
# Out:
# 94/94 [==============================] - 39s 415ms/step - loss: 0.1300 - accuracy: 0.9457 - precision: 0.9457 - recall: 0.9457 - auc: 0.9895 - f1_Score: 0.9455

# %%
print(f"Test Loss:     {test_loss}")
print(f"Test Accuracy: {test_accuracy}")
print(f"Test Precision: {test_precision}")
print(f"Test Recall: {test_recall}")
print(f"Test AUC: {test_auc}")
print(f"Test F1_Score: {np.mean(test_F1_Score)}")
# Out:
# Test Loss:     0.12997056543827057
# Test Accuracy: 0.9456666707992554
# Test Precision: 0.9456666707992554
# Test Recall: 0.9456666707992554
# Test AUC: 0.9894880652427673
# Test F1_Score: 0.9455136060714722

# %% [markdown]
# ## **8. Plotting the Classification Metrics**
# ### i. Confusion Matrix

# %%
y_pred = np.argmax(predictions, axis=1)
y_true = test_generator.classes

# %%
cf_mtx = confusion_matrix(y_true, y_pred)

group_counts = ["{0:0.0f}".format(value) for value in cf_mtx.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in cf_mtx.flatten()/np.sum(cf_mtx)]
box_labels = [f"{v1}\n({v2})" for v1, v2 in zip(group_counts, group_percentages)]
box_labels = np.asarray(box_labels).reshape(2, 2)

plt.figure(figsize = (12, 10))
sns.heatmap(cf_mtx, xticklabels=labels.values(), yticklabels=labels.values(),
           cmap="YlGnBu", fmt="", annot=box_labels)
plt.xlabel('Predicted Classes')
plt.ylabel('True Classes')
plt.show()

# %%
print(classification_report(y_true, y_pred, target_names=labels.values()))
# Out:
#               precision    recall  f1-score   support
#
#      Nonnude       1.00      0.89      0.94      1500
#         Nude       0.90      1.00      0.95      1500
#
#     accuracy                           0.95      3000
#    macro avg       0.95      0.95      0.95      3000
# weighted avg       0.95      0.95      0.95      3000

# %%
A=history.history['accuracy']
A_v=history.history['val_accuracy']
L=history.history['loss']
L_v=history.history['val_loss']
Auc=history.history['auc']
Auc_v=history.history['val_auc']
P=history.history['precision']
P_v=history.history['val_precision']
F1=history.history['f1_Score']
F1_v=history.history['val_f1_Score']
import pandas as pd
data_to_submit = pd.DataFrame({
    'accuracy':A,
    'val_accuracy':A_v,
    'loss': L,
    'val_loss': L_v,
    'auc':Auc,
    'val_auc':Auc_v,
    'precision':P,
    'val_precision':P_v,
    'f1_score':F1,
    'val_f1_score':F1_v
})
data_to_submit.to_csv('EffectiveNetV2L.csv', index = False)
