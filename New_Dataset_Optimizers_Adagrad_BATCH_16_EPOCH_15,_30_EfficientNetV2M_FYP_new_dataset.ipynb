# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## **Importing necessary packages**

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import cv2
import os

import warnings
warnings.filterwarnings('ignore')

from sklearn.metrics import confusion_matrix, classification_report

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation, BatchNormalization, Conv2D, Dense, Dropout, Flatten, MaxPool2D,MaxPooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping

# %% [markdown]
# ## **2. Load the Image Training and Validation Datasets**
#
# ### i. Get the Image Dataset Paths

# %%
train_dataset_path = '/content/drive/MyDrive/FYP/train'
validation_dataset_path = '/content/drive/MyDrive/FYP/val'

# %% [markdown]
# ### ii. Load Image Datasets and Apply Augmentations
# Since the images present in the datasets are 150x150px in size, the image height and width are taken as 150, 150 respectively. The batch size value can be changed if required.

# %%
IMG_WIDTH = 150
IMG_HEIGHT = 150
BATCH_SIZE = 16

# %% [markdown]
# Loading the training dataset and applying augmentations on it.

# %%
train_datagen = ImageDataGenerator(rescale=1.0/255,
                                  zoom_range=0.2,
                                  width_shift_range=0.2,
                                  height_shift_range=0.2,
                                  fill_mode='nearest')
train_generator = train_datagen.flow_from_directory(train_dataset_path,
                                                   target_size=(IMG_WIDTH, IMG_HEIGHT),
                                                   batch_size=BATCH_SIZE,
                                                   class_mode='categorical',
                                                   shuffle=True)
# Out:
# Found 3009 images belonging to 2 classes.

# %% [markdown]
# Loading the validation dataset.

# %%
validation_datagen = ImageDataGenerator(rescale=1.0/255)
validation_generator = validation_datagen.flow_from_directory(validation_dataset_path,
                                                             target_size=(IMG_WIDTH, IMG_HEIGHT),
                                                             batch_size=BATCH_SIZE,
                                                             class_mode='categorical',
                                                             shuffle=True)
# Out:
# Found 3019 images belonging to 2 classes.

# %% [markdown]
# ### iii. Get the Label Mappings
# The labels dictionary is made in order to retrive the class names against the label indices used for training the model

# %%
labels = {value: key for key, value in train_generator.class_indices.items()}

print("Label Mappings for classes present in the training and validation datasets\n")
for key, value in labels.items():
    print(f"{key} : {value}")
# Out:
# Label Mappings for classes present in the training and validation datasets
#
# 0 : Nonnude
# 1 : Nude

# %% [markdown]
# ## **3. Plotting Sample Training Image**s

# %%
fig, ax = plt.subplots(nrows=2, ncols=5, figsize=(15, 12))
idx = 0

for i in range(2):
    for j in range(5):
        label = labels[np.argmax(train_generator[0][1][idx])]
        ax[i, j].set_title(f"{label}")
        ax[i, j].imshow(train_generator[0][0][idx][:, :, :])
        ax[i, j].axis("off")
        idx += 1

plt.tight_layout()
plt.suptitle("Sample Training Images", fontsize=21)
plt.show()

# %% [markdown]
# ## **4. Training a EfficientNetV2M Model**
#
#
# ### i. Create a EfficientNetV2M Model

# %%
base_model = tf.keras.applications.EfficientNetV2M(
                     include_top=False,
                     weights='imagenet',
                     input_shape=(150,150,3),
                     include_preprocessing=True
                     )

base_model.trainable=True
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/efficientnet_v2/efficientnetv2-m_notop.h5
# 214201816/214201816 [==============================] - 10s 0us/step

# %%
model = tf.keras.Sequential([
        base_model,  
        tf.keras.layers.BatchNormalization(renorm=True),
        tf.keras.layers.GlobalAveragePooling2D(),
        tf.keras.layers.Dense(512, activation='relu'),
        tf.keras.layers.Dense(256, activation='relu'),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.Dense(128, activation='relu'),
        tf.keras.layers.Dense(2, activation='softmax')
    ])

# %%
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  efficientnetv2-m (Functiona  (None, 5, 5, 1280)       53150388
#  l)
#
#  batch_normalization (BatchN  (None, 5, 5, 1280)       8960
#  ormalization)
#
#  global_average_pooling2d (G  (None, 1280)             0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 512)               655872
#
#  dense_1 (Dense)             (None, 256)               131328
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_2 (Dense)             (None, 128)               32896
#
#  dense_3 (Dense)             (None, 2)                 258
#
# =================================================================
# Total params: 53,979,702
# Trainable params: 53,681,270
# Non-trainable params: 298,432
# _________________________________________________________________
# None

# %% [markdown]
# ### ii. Defining Callbacks
# A callback is an object that can perform actions at various stages of training (e.g. at the start or end of an epoch, before or after a single batch, etc)
#
# a. Reduce Learning Rate on Plateau
# Is used to reduce the learning rate when a metric has stopped improving.

# %%
# !pip install tensorflow_addons
import tensorflow_addons as tfa
METRICS = [
      # tf.keras.metrics.BinaryAccuracy(name='binary_accuracy'),
      # tf.keras.metrics.Accuracy(name='accuracy'),
      tf.keras.metrics.CategoricalAccuracy(name='accuracy'),
      tf.keras.metrics.Precision(name='precision'),
      tf.keras.metrics.Recall(name='recall'),  
      tf.keras.metrics.AUC(name='auc'),
      # tf.keras.metrics.F1Score(name='F1'),
      tfa.metrics.F1Score(num_classes= 2,name="f1_Score")

    
]
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tensorflow_addons
#   Downloading tensorflow_addons-0.19.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 52.9 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from tensorflow_addons) (23.0)
# Collecting typeguard>=2.7
#   Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Installing collected packages: typeguard, tensorflow_addons
# Successfully installed tensorflow_addons-0.19.0 typeguard-2.13.3

# %%
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=np.sqrt(0.1), patience=5)
# early = tf.keras.callbacks.EarlyStopping( patience=10,
#                                           min_delta=0.001,
#                                           restore_best_weights=True)

# %% [markdown]
# ### iii. Defining the Optimizer

# %%
optimizer = tf.optimizers.Adagrad(learning_rate=0.001)

# %% [markdown]
# ### iv. Compile the Model

# %%
# cnn_model.compile(optimizer=optimizer, loss=CategoricalCrossentropy(), metrics=['accuracy'])
model.compile(optimizer=optimizer,loss='categorical_crossentropy',metrics=METRICS)

# %% [markdown]
# ### v. Training the Model

# %%
history = model.fit(train_generator,
                    steps_per_epoch=15,
                    validation_data=validation_generator,
                    validation_steps=2,
                    epochs=30,verbose = 2,
                    callbacks=[reduce_lr])
# Out:
# Epoch 1/30
# WARNING:tensorflow:From /usr/local/lib/python3.9/dist-packages/tensorflow/python/autograph/pyct/static_analysis/liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089
# 15/15 - 296s - loss: 0.7101 - accuracy: 0.4917 - precision: 0.4917 - recall: 0.4917 - auc: 0.4834 - f1_Score: 0.4444 - val_loss: 0.6955 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.4619 - val_f1_Score: 0.4459 - lr: 0.0010 - 296s/epoch - 20s/step
# Epoch 2/30
# 15/15 - 170s - loss: 0.6891 - accuracy: 0.5292 - precision: 0.5292 - recall: 0.5292 - auc: 0.5500 - f1_Score: 0.5069 - val_loss: 0.6868 - val_accuracy: 0.4688 - val_precision: 0.4688 - val_recall: 0.4688 - val_auc: 0.5537 - val_f1_Score: 0.3191 - lr: 0.0010 - 170s/epoch - 11s/step
# Epoch 3/30
# 15/15 - 153s - loss: 0.7061 - accuracy: 0.4917 - precision: 0.4917 - recall: 0.4917 - auc: 0.5009 - f1_Score: 0.4836 - val_loss: 0.6758 - val_accuracy: 0.5625 - val_precision: 0.5625 - val_recall: 0.5625 - val_auc: 0.6226 - val_f1_Score: 0.4909 - lr: 0.0010 - 153s/epoch - 10s/step
# Epoch 4/30
# 15/15 - 138s - loss: 0.6861 - accuracy: 0.5542 - precision: 0.5542 - recall: 0.5542 - auc: 0.5639 - f1_Score: 0.5234 - val_loss: 0.6485 - val_accuracy: 0.6250 - val_precision: 0.6250 - val_recall: 0.6250 - val_auc: 0.7471 - val_f1_Score: 0.5844 - lr: 0.0010 - 138s/epoch - 9s/step
# Epoch 5/30
# 15/15 - 139s - loss: 0.6897 - accuracy: 0.5467 - precision: 0.5467 - recall: 0.5467 - auc: 0.5558 - f1_Score: 0.5410 - val_loss: 0.7004 - val_accuracy: 0.4375 - val_precision: 0.4375 - val_recall: 0.4375 - val_auc: 0.5020 - val_f1_Score: 0.4375 - lr: 0.0010 - 139s/epoch - 9s/step
# Epoch 6/30
# 15/15 - 129s - loss: 0.6686 - accuracy: 0.6083 - precision: 0.6083 - recall: 0.6083 - auc: 0.6428 - f1_Score: 0.5971 - val_loss: 0.6555 - val_accuracy: 0.6250 - val_precision: 0.6250 - val_recall: 0.6250 - val_auc: 0.7310 - val_f1_Score: 0.6250 - lr: 0.0010 - 129s/epoch - 9s/step
# Epoch 7/30
# 15/15 - 113s - loss: 0.6784 - accuracy: 0.5733 - precision: 0.5733 - recall: 0.5733 - auc: 0.6059 - f1_Score: 0.5539 - val_loss: 0.6658 - val_accuracy: 0.6250 - val_precision: 0.6250 - val_recall: 0.6250 - val_auc: 0.6738 - val_f1_Score: 0.6190 - lr: 0.0010 - 113s/epoch - 8s/step
# Epoch 8/30
# 15/15 - 116s - loss: 0.6790 - accuracy: 0.5958 - precision: 0.5958 - recall: 0.5958 - auc: 0.5920 - f1_Score: 0.5942 - val_loss: 0.5999 - val_accuracy: 0.8750 - val_precision: 0.8750 - val_recall: 0.8750 - val_auc: 0.8955 - val_f1_Score: 0.8730 - lr: 0.0010 - 116s/epoch - 8s/step
# Epoch 9/30
# 15/15 - 112s - loss: 0.6757 - accuracy: 0.5708 - precision: 0.5708 - recall: 0.5708 - auc: 0.6101 - f1_Score: 0.5696 - val_loss: 0.6791 - val_accuracy: 0.6562 - val_precision: 0.6562 - val_recall: 0.6562 - val_auc: 0.6299 - val_f1_Score: 0.5883 - lr: 0.0010 - 112s/epoch - 7s/step
# Epoch 10/30
# 15/15 - 105s - loss: 0.6574 - accuracy: 0.6083 - precision: 0.6083 - recall: 0.6083 - auc: 0.6610 - f1_Score: 0.6079 - val_loss: 0.6150 - val_accuracy: 0.8125 - val_precision: 0.8125 - val_recall: 0.8125 - val_auc: 0.8218 - val_f1_Score: 0.8057 - lr: 0.0010 - 105s/epoch - 7s/step
# Epoch 11/30
# 15/15 - 79s - loss: 0.6605 - accuracy: 0.6178 - precision: 0.6178 - recall: 0.6178 - auc: 0.6545 - f1_Score: 0.6144 - val_loss: 0.6290 - val_accuracy: 0.6562 - val_precision: 0.6562 - val_recall: 0.6562 - val_auc: 0.7705 - val_f1_Score: 0.6559 - lr: 0.0010 - 79s/epoch - 5s/step
# Epoch 12/30
# 15/15 - 78s - loss: 0.6636 - accuracy: 0.6000 - precision: 0.6000 - recall: 0.6000 - auc: 0.6465 - f1_Score: 0.5982 - val_loss: 0.6536 - val_accuracy: 0.6875 - val_precision: 0.6875 - val_recall: 0.6875 - val_auc: 0.6821 - val_f1_Score: 0.6863 - lr: 0.0010 - 78s/epoch - 5s/step
# Epoch 13/30
# 15/15 - 80s - loss: 0.6495 - accuracy: 0.6750 - precision: 0.6750 - recall: 0.6750 - auc: 0.6962 - f1_Score: 0.6748 - val_loss: 0.6427 - val_accuracy: 0.6562 - val_precision: 0.6562 - val_recall: 0.6562 - val_auc: 0.6826 - val_f1_Score: 0.6559 - lr: 0.0010 - 80s/epoch - 5s/step
# Epoch 14/30
# 15/15 - 70s - loss: 0.6266 - accuracy: 0.6708 - precision: 0.6708 - recall: 0.6708 - auc: 0.7285 - f1_Score: 0.6701 - val_loss: 0.5894 - val_accuracy: 0.7188 - val_precision: 0.7188 - val_recall: 0.7188 - val_auc: 0.8442 - val_f1_Score: 0.7046 - lr: 3.1623e-04 - 70s/epoch - 5s/step
# Epoch 15/30
# 15/15 - 69s - loss: 0.6165 - accuracy: 0.6833 - precision: 0.6833 - recall: 0.6833 - auc: 0.7327 - f1_Score: 0.6823 - val_loss: 0.6091 - val_accuracy: 0.6250 - val_precision: 0.6250 - val_recall: 0.6250 - val_auc: 0.7520 - val_f1_Score: 0.6235 - lr: 3.1623e-04 - 69s/epoch - 5s/step
# Epoch 16/30
# 15/15 - 62s - loss: 0.6247 - accuracy: 0.6958 - precision: 0.6958 - recall: 0.6958 - auc: 0.7315 - f1_Score: 0.6956 - val_loss: 0.6242 - val_accuracy: 0.6875 - val_precision: 0.6875 - val_recall: 0.6875 - val_auc: 0.7188 - val_f1_Score: 0.6863 - lr: 3.1623e-04 - 62s/epoch - 4s/step
# Epoch 17/30
# 15/15 - 60s - loss: 0.6068 - accuracy: 0.6917 - precision: 0.6917 - recall: 0.6917 - auc: 0.7543 - f1_Score: 0.6916 - val_loss: 0.5862 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - val_auc: 0.8237 - val_f1_Score: 0.6908 - lr: 3.1623e-04 - 60s/epoch - 4s/step
# Epoch 18/30
# 15/15 - 58s - loss: 0.6239 - accuracy: 0.6542 - precision: 0.6542 - recall: 0.6542 - auc: 0.7288 - f1_Score: 0.6537 - val_loss: 0.6397 - val_accuracy: 0.6875 - val_precision: 0.6875 - val_recall: 0.6875 - val_auc: 0.6860 - val_f1_Score: 0.6537 - lr: 3.1623e-04 - 58s/epoch - 4s/step
# Epoch 19/30
# 15/15 - 61s - loss: 0.5707 - accuracy: 0.7375 - precision: 0.7375 - recall: 0.7375 - auc: 0.8111 - f1_Score: 0.7375 - val_loss: 0.5568 - val_accuracy: 0.7188 - val_precision: 0.7188 - val_recall: 0.7188 - val_auc: 0.8506 - val_f1_Score: 0.6632 - lr: 3.1623e-04 - 61s/epoch - 4s/step
# Epoch 20/30
# 15/15 - 56s - loss: 0.6103 - accuracy: 0.6875 - precision: 0.6875 - recall: 0.6875 - auc: 0.7334 - f1_Score: 0.6841 - val_loss: 0.5122 - val_accuracy: 0.7812 - val_precision: 0.7812 - val_recall: 0.7812 - val_auc: 0.9106 - val_f1_Score: 0.7625 - lr: 3.1623e-04 - 56s/epoch - 4s/step
# Epoch 21/30
# 15/15 - 49s - loss: 0.5846 - accuracy: 0.7042 - precision: 0.7042 - recall: 0.7042 - auc: 0.7718 - f1_Score: 0.7035 - val_loss: 0.5908 - val_accuracy: 0.6875 - val_precision: 0.6875 - val_recall: 0.6875 - val_auc: 0.7998 - val_f1_Score: 0.6364 - lr: 3.1623e-04 - 49s/epoch - 3s/step
# Epoch 22/30
# 15/15 - 46s - loss: 0.6284 - accuracy: 0.6583 - precision: 0.6583 - recall: 0.6583 - auc: 0.7186 - f1_Score: 0.6543 - val_loss: 0.4515 - val_accuracy: 0.8750 - val_precision: 0.8750 - val_recall: 0.8750 - val_auc: 0.9580 - val_f1_Score: 0.8704 - lr: 3.1623e-04 - 46s/epoch - 3s/step
# Epoch 23/30
# 15/15 - 39s - loss: 0.5744 - accuracy: 0.6933 - precision: 0.6933 - recall: 0.6933 - auc: 0.7869 - f1_Score: 0.6914 - val_loss: 0.4796 - val_accuracy: 0.7812 - val_precision: 0.7812 - val_recall: 0.7812 - val_auc: 0.9053 - val_f1_Score: 0.7793 - lr: 3.1623e-04 - 39s/epoch - 3s/step
# Epoch 24/30
# 15/15 - 45s - loss: 0.5855 - accuracy: 0.7125 - precision: 0.7125 - recall: 0.7125 - auc: 0.7895 - f1_Score: 0.7117 - val_loss: 0.5667 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - val_auc: 0.8184 - val_f1_Score: 0.6667 - lr: 3.1623e-04 - 45s/epoch - 3s/step
# Epoch 25/30
# 15/15 - 44s - loss: 0.5398 - accuracy: 0.7875 - precision: 0.7875 - recall: 0.7875 - auc: 0.8441 - f1_Score: 0.7844 - val_loss: 0.4668 - val_accuracy: 0.8438 - val_precision: 0.8438 - val_recall: 0.8438 - val_auc: 0.9141 - val_f1_Score: 0.8424 - lr: 3.1623e-04 - 44s/epoch - 3s/step
# Epoch 26/30
# 15/15 - 44s - loss: 0.5681 - accuracy: 0.7417 - precision: 0.7417 - recall: 0.7417 - auc: 0.8186 - f1_Score: 0.7386 - val_loss: 0.5054 - val_accuracy: 0.8438 - val_precision: 0.8438 - val_recall: 0.8438 - val_auc: 0.9004 - val_f1_Score: 0.8359 - lr: 3.1623e-04 - 44s/epoch - 3s/step
# Epoch 27/30
# 15/15 - 36s - loss: 0.5608 - accuracy: 0.7375 - precision: 0.7375 - recall: 0.7375 - auc: 0.8027 - f1_Score: 0.7375 - val_loss: 0.5815 - val_accuracy: 0.7188 - val_precision: 0.7188 - val_recall: 0.7188 - val_auc: 0.7837 - val_f1_Score: 0.7117 - lr: 3.1623e-04 - 36s/epoch - 2s/step
# Epoch 28/30
# 15/15 - 40s - loss: 0.5543 - accuracy: 0.7708 - precision: 0.7708 - recall: 0.7708 - auc: 0.8146 - f1_Score: 0.7706 - val_loss: 0.4716 - val_accuracy: 0.8125 - val_precision: 0.8125 - val_recall: 0.8125 - val_auc: 0.9277 - val_f1_Score: 0.7818 - lr: 1.0000e-04 - 40s/epoch - 3s/step
# Epoch 29/30
# 15/15 - 38s - loss: 0.5823 - accuracy: 0.6917 - precision: 0.6917 - recall: 0.6917 - auc: 0.7709 - f1_Score: 0.6886 - val_loss: 0.6107 - val_accuracy: 0.6250 - val_precision: 0.6250 - val_recall: 0.6250 - val_auc: 0.7100 - val_f1_Score: 0.6190 - lr: 1.0000e-04 - 38s/epoch - 3s/step
# Epoch 30/30
# 15/15 - 32s - loss: 0.5335 - accuracy: 0.7500 - precision: 0.7500 - recall: 0.7500 - auc: 0.8355 - f1_Score: 0.7466 - val_loss: 0.6351 - val_accuracy: 0.6250 - val_precision: 0.6250 - val_recall: 0.6250 - val_auc: 0.7285 - val_f1_Score: 0.6190 - lr: 1.0000e-04 - 32s/epoch - 2s/step

# %% [markdown]
# ## **5. Plotting the Model Metrics**
# ### i. Plotting training and validation accuracy, loss and learning rate

# %%
plt.figure( figsize = (15,8)) 
    
plt.subplot(221)  
# Accuracy 
plt.plot(model.history.history['accuracy'])
plt.plot(model.history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Training set', 'Validation set'], loc='upper left')
plt.show()


# Loss
plt.figure( figsize = (15,8)) 
plt.subplot(222)  
plt.plot(model.history.history['loss'])
plt.plot(model.history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Training set', 'Validation set'], loc='upper left')
plt.show()

# %%
train_accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

train_loss = history.history['loss']
val_loss = history.history['val_loss']

learning_rate = history.history['lr']
# ans = history.history['val_auc']
# ans

# %%
train_accuracy
# Out:
# [0.49166667461395264,
#  0.5291666388511658,
#  0.49166667461395264,
#  0.5541666746139526,
#  0.54666668176651,
#  0.6083333492279053,
#  0.5733333230018616,
#  0.5958333611488342,
#  0.5708333253860474,
#  0.6083333492279053,
#  0.6177777647972107,
#  0.6000000238418579,
#  0.675000011920929,
#  0.6708333492279053,
#  0.6833333373069763,
#  0.6958333253860474,
#  0.6916666626930237,
#  0.6541666388511658,
#  0.737500011920929,
#  0.6875,
#  0.7041666507720947,
#  0.6583333611488342,
#  0.6933333277702332,
#  0.7124999761581421,
#  0.7875000238418579,
#  0.7416666746139526,
#  0.737500011920929,
#  0.7708333134651184,
#  0.6916666626930237,
#  0.75]

# %%
fig, ax = plt.subplots(nrows=3, ncols=1, figsize=(12, 10))

ax[0].set_title('Training Accuracy vs. Epochs')
ax[0].plot(train_accuracy, 'o-', label='Train Accuracy')
ax[0].plot(val_accuracy, 'o-', label='Validation Accuracy')
ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Accuracy')
ax[0].legend(loc='best')

ax[1].set_title('Training/Validation Loss vs. Epochs')
ax[1].plot(train_loss, 'o-', label='Train Loss')
ax[1].plot(val_loss, 'o-', label='Validation Loss')
ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Loss')
ax[1].legend(loc='best')

ax[2].set_title('Learning Rate vs. Epochs')
ax[2].plot(learning_rate, 'o-', label='Learning Rate')
ax[2].set_xlabel('Epochs')
ax[2].set_ylabel('Loss')
ax[2].legend(loc='best')

plt.tight_layout()
plt.show()

# %%
def Train_Val_Plot(acc,val_acc,loss,val_loss,auc,val_auc,precision,val_precision,f1_Score,val_f1_Score):
    
    fig, (ax1, ax2,ax3,ax4,ax5) = plt.subplots(1,5, figsize= (20,5))
    fig.suptitle(" MODEL'S METRICS VISUALIZATION ")

    ax1.plot(range(1, len(acc) + 1), acc)
    ax1.plot(range(1, len(val_acc) + 1), val_acc)
    ax1.set_title('History of Accuracy')
    ax1.set_xlabel('Epochs')
    ax1.set_ylabel('Accuracy')
    ax1.legend(['training', 'validation'])


    ax2.plot(range(1, len(loss) + 1), loss)
    ax2.plot(range(1, len(val_loss) + 1), val_loss)
    ax2.set_title('History of Loss')
    ax2.set_xlabel('Epochs')
    ax2.set_ylabel('Loss')
    ax2.legend(['training', 'validation'])
    
    ax3.plot(range(1, len(auc) + 1), auc)
    ax3.plot(range(1, len(val_auc) + 1), val_auc)
    ax3.set_title('History of AUC')
    ax3.set_xlabel('Epochs')
    ax3.set_ylabel('AUC')
    ax3.legend(['training', 'validation'])
    
    ax4.plot(range(1, len(precision) + 1), precision)
    ax4.plot(range(1, len(val_precision) + 1), val_precision)
    ax4.set_title('History of Precision')
    ax4.set_xlabel('Epochs')
    ax4.set_ylabel('Precision')
    ax4.legend(['training', 'validation'])
    
    ax5.plot(range(1, len(f1_Score) + 1), f1_Score)
    ax5.plot(range(1, len(val_f1_Score) + 1), val_f1_Score)
    ax5.set_title('History of F1-score')
    ax5.set_xlabel('Epochs')
    ax5.set_ylabel('F1 score')
    ax5.legend(['training', 'validation'])


    plt.show()
    
import numpy as np
# f1_s= np.mean(history.history['f1_Score'])
# val_f1_s= np.mean(history.history['val_f1_Score'])
Train_Val_Plot(history.history['accuracy'],history.history['val_accuracy'],
               history.history['loss'],history.history['val_loss'],
               history.history['auc'],history.history['val_auc'],
               history.history['precision'],history.history['val_precision']
              #  f1_s,val_f1_s

                , history.history['f1_Score'],history.history['val_f1_Score']
              )

# %% [markdown]
# ## 6. Testing the Model on Test Set
# Testing the model on the validation dataset because a seperate dataset for testing is not available.

# %%
test_dataset = '/content/drive/MyDrive/FYP/test'

# %%
test_datagen = ImageDataGenerator(rescale=1.0/255)

test_generator = test_datagen.flow_from_directory(test_dataset,
                                                 shuffle=False,
                                                 batch_size=BATCH_SIZE,
                                                 target_size = (IMG_WIDTH, IMG_HEIGHT),
                                                 class_mode='categorical')
# Out:
# Found 3000 images belonging to 2 classes.

# %% [markdown]
# ## 7. Model Prediction on the Test Dataset

# %%
predictions = model.predict(test_generator)
# Out:
# 188/188 [==============================] - 909s 5s/step

# %%
fig, ax = plt.subplots(nrows=2, ncols=5, figsize=(12, 10))
idx = 0

for i in range(2):
    for j in range(5):
        predicted_label = labels[np.argmax(predictions[idx])]
        ax[i, j].set_title(f"{predicted_label}")
        ax[i, j].imshow(test_generator[0][0][idx])
        ax[i, j].axis("off")
        idx += 1

plt.tight_layout()
plt.suptitle("Test Dataset Predictions", fontsize=20)
plt.show()

# %%
train_loss, train_accuracy, train_precision, train_recall, train_auc, train_F1_Score = model.evaluate(train_generator, batch_size=BATCH_SIZE)
# Out:
# 189/189 [==============================] - 178s 947ms/step - loss: 0.5329 - accuracy: 0.7385 - precision: 0.7385 - recall: 0.7385 - auc: 0.8311 - f1_Score: 0.7320

# %%
print(f"Train Loss:     {train_loss}")
print(f"Train Accuracy: {train_accuracy}")
print(f"Train Precision: {train_precision}")
print(f"Train Recall: {train_recall}")
print(f"Train AUC: {train_auc}")
print(f"Train F1_Score: {np.mean(train_F1_Score)}")
# Out:
# Train Loss:     0.5329399108886719
# Train Accuracy: 0.7384513020515442
# Train Precision: 0.7384513020515442
# Train Recall: 0.7384513020515442
# Train AUC: 0.8310853242874146
# Train F1_Score: 0.732024073600769

# %%
test_loss, test_accuracy, test_precision, test_recall, test_auc, test_F1_Score = model.evaluate(test_generator, batch_size=BATCH_SIZE)
# Out:
# 188/188 [==============================] - 33s 176ms/step - loss: 0.5397 - accuracy: 0.7283 - precision: 0.7283 - recall: 0.7283 - auc: 0.8250 - f1_Score: 0.7183

# %%
print(f"Test Loss:     {test_loss}")
print(f"Test Accuracy: {test_accuracy}")
print(f"Test Precision: {test_precision}")
print(f"Test Recall: {test_recall}")
print(f"Test AUC: {test_auc}")
print(f"Test F1_Score: {np.mean(test_F1_Score)}")
# Out:
# Test Loss:     0.5397425293922424
# Test Accuracy: 0.7283333539962769
# Test Precision: 0.7283333539962769
# Test Recall: 0.7283333539962769
# Test AUC: 0.8249872922897339
# Test F1_Score: 0.7182695865631104

# %% [markdown]
# ## **8. Plotting the Classification Metrics**
# ### i. Confusion Matrix

# %%
y_pred = np.argmax(predictions, axis=1)
y_true = test_generator.classes

# %%
cf_mtx = confusion_matrix(y_true, y_pred)

group_counts = ["{0:0.0f}".format(value) for value in cf_mtx.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in cf_mtx.flatten()/np.sum(cf_mtx)]
box_labels = [f"{v1}\n({v2})" for v1, v2 in zip(group_counts, group_percentages)]
box_labels = np.asarray(box_labels).reshape(2, 2)

plt.figure(figsize = (12, 10))
sns.heatmap(cf_mtx, xticklabels=labels.values(), yticklabels=labels.values(),
           cmap="YlGnBu", fmt="", annot=box_labels)
plt.xlabel('Predicted Classes')
plt.ylabel('True Classes')
plt.show()

# %%
print(classification_report(y_true, y_pred, target_names=labels.values()))
# Out:
#               precision    recall  f1-score   support
#
#      Nonnude       0.67      0.92      0.77      1500
#         Nude       0.87      0.54      0.67      1500
#
#     accuracy                           0.73      3000
#    macro avg       0.77      0.73      0.72      3000
# weighted avg       0.77      0.73      0.72      3000

# %%
A=history.history['accuracy']
A_v=history.history['val_accuracy']
L=history.history['loss']
L_v=history.history['val_loss']
Auc=history.history['auc']
Auc_v=history.history['val_auc']
P=history.history['precision']
P_v=history.history['val_precision']
F1=history.history['f1_Score']
F1_v=history.history['val_f1_Score']

# %%
import pandas as pd
data_to_submit = pd.DataFrame({
    'accuracy':A,
    'val_accuracy':A_v,
    'loss': L,
    'val_loss': L_v,
    'auc':Auc,
    'val_auc':Auc_v,
    'precision':P,
    'val_precision':P_v,
    'f1_score':F1,
    'val_f1_score':F1_v
})
data_to_submit.to_csv('csv_to_submit.csv', index = False)
