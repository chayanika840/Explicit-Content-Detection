# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## **Importing necessary packages**

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import cv2
import os
import warnings
warnings.filterwarnings('ignore')

from sklearn.metrics import confusion_matrix, classification_report

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation, BatchNormalization, Conv2D, Dense, Dropout, Flatten, MaxPool2D,MaxPooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping

# %% [markdown]
# ## **2. Load the Image Training and Validation Datasets**
#
# ### i. Get the Image Dataset Paths

# %%
train_dataset_path = '/content/drive/MyDrive/FYP/train'
validation_dataset_path = '/content/drive/MyDrive/FYP/val'

# %% [markdown]
# ### ii. Load Image Datasets and Apply Augmentations
# Since the images present in the datasets are 150x150px in size, the image height and width are taken as 150, 150 respectively. The batch size value can be changed if required.

# %%
#if again dat value error comes then change the image width=48, image height =48
IMG_WIDTH = 150
IMG_HEIGHT = 150
BATCH_SIZE = 32

# %% [markdown]
# Loading the training dataset and applying augmentations on it.

# %%
train_datagen = ImageDataGenerator(rescale=1.0/255,
                                  zoom_range=0.2,
                                  width_shift_range=0.2,
                                  height_shift_range=0.2,
                                  fill_mode='nearest')
train_generator = train_datagen.flow_from_directory(train_dataset_path,
                                                   target_size=(IMG_WIDTH, IMG_HEIGHT),
                                                   batch_size=BATCH_SIZE,
                                                   class_mode='categorical',
                                                   shuffle=True)
# Out:
# Found 3009 images belonging to 2 classes.

# %% [markdown]
# Loading the validation dataset.

# %%
validation_datagen = ImageDataGenerator(rescale=1.0/255)
validation_generator = validation_datagen.flow_from_directory(validation_dataset_path,
                                                             target_size=(IMG_WIDTH, IMG_HEIGHT),
                                                             batch_size=BATCH_SIZE,
                                                             class_mode='categorical',
                                                             shuffle=True)
# Out:
# Found 3019 images belonging to 2 classes.

# %% [markdown]
# ### iii. Get the Label Mappings
# The labels dictionary is made in order to retrive the class names against the label indices used for training the model

# %%
labels = {value: key for key, value in train_generator.class_indices.items()}

print("Label Mappings for classes present in the training and validation datasets\n")
for key, value in labels.items():
    print(f"{key} : {value}")
# Out:
# Label Mappings for classes present in the training and validation datasets
#
# 0 : Nonnude
# 1 : Nude

# %% [markdown]
# ## **3. Plotting Sample Training Image**s

# %%
fig, ax = plt.subplots(nrows=2, ncols=5, figsize=(15, 12))
idx = 0

for i in range(2):
    for j in range(5):
        label = labels[np.argmax(train_generator[0][1][idx])]
        ax[i, j].set_title(f"{label}")
        ax[i, j].imshow(train_generator[0][0][idx][:, :, :])
        ax[i, j].axis("off")
        idx += 1

plt.tight_layout()
plt.suptitle("Sample Training Images", fontsize=21)
plt.show()

# %% [markdown]
# ## **4. Training a InceptionResNetV2 Model**
#
#
# ### i. Create a InceptionResNetV2 Model

# %%
base_model = tf.keras.applications.EfficientNetV2L(
                     include_top=False,
                     weights='imagenet',
                     input_shape=(150,150,3),
                     include_preprocessing=True

                     )

base_model.trainable=True
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/efficientnet_v2/efficientnetv2-l_notop.h5
# 473176280/473176280 [==============================] - 21s 0us/step

# %%
model = tf.keras.Sequential([
        base_model,  
        tf.keras.layers.BatchNormalization(renorm=True),
        tf.keras.layers.GlobalAveragePooling2D(),
        tf.keras.layers.Dense(512, activation='relu'),
        tf.keras.layers.Dense(256, activation='relu'),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.Dense(128, activation='relu'),
        tf.keras.layers.Dense(2, activation='softmax')
    ])

# %%
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  efficientnetv2-l (Functiona  (None, 5, 5, 1280)       117746848
#  l)
#
#  batch_normalization (BatchN  (None, 5, 5, 1280)       8960
#  ormalization)
#
#  global_average_pooling2d (G  (None, 1280)             0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 512)               655872
#
#  dense_1 (Dense)             (None, 256)               131328
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_2 (Dense)             (None, 128)               32896
#
#  dense_3 (Dense)             (None, 2)                 258
#
# =================================================================
# Total params: 118,576,162
# Trainable params: 118,057,186
# Non-trainable params: 518,976
# _________________________________________________________________
# None

# %% [markdown]
# ### ii. Defining Callbacks
# A callback is an object that can perform actions at various stages of training (e.g. at the start or end of an epoch, before or after a single batch, etc)
#
# a. Reduce Learning Rate on Plateau
# Is used to reduce the learning rate when a metric has stopped improving.

# %%
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=np.sqrt(0.1), patience=5)
early = tf.keras.callbacks.EarlyStopping( patience=10,
                                          min_delta=0.001,
                                          restore_best_weights=True)

# %%
# !pip install tensorflow_addons
import tensorflow_addons as tfa
METRICS = [
      # tf.keras.metrics.BinaryAccuracy(name='binary_accuracy'),
      # tf.keras.metrics.Accuracy(name='accuracy'),
      tf.keras.metrics.CategoricalAccuracy(name='accuracy'),
      tf.keras.metrics.Precision(name='precision'),
      tf.keras.metrics.Recall(name='recall'),  
      tf.keras.metrics.AUC(name='auc'),
      # tf.keras.metrics.F1Score(name='F1'),
      tfa.metrics.F1Score(num_classes= 2,name="f1_Score")

    
]
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tensorflow_addons
#   Downloading tensorflow_addons-0.19.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 52.9 MB/s eta 0:00:00
# Collecting typeguard>=2.7
#   Downloading typeguard-3.0.1-py3-none-any.whl (30 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from tensorflow_addons) (23.0)
# Requirement already satisfied: typing-extensions>=4.4.0 in /usr/local/lib/python3.9/dist-packages (from typeguard>=2.7->tensorflow_addons) (4.5.0)
# Requirement already satisfied: importlib-metadata>=3.6 in /usr/local/lib/python3.9/dist-packages (from typeguard>=2.7->tensorflow_addons) (6.0.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.9/dist-packages (from importlib-metadata>=3.6->typeguard>=2.7->tensorflow_addons) (3.15.0)
# Installing collected packages: typeguard, tensorflow_addons
# Successfully installed tensorflow_addons-0.19.0 typeguard-3.0.1

# %% [markdown]
# ### iii. Defining the Optimizer

# %%
optimizer = tf.optimizers.Adamax(learning_rate=0.001)

# %% [markdown]
# ### iv. Compile the Model

# %%
# cnn_model.compile(optimizer=optimizer, loss=CategoricalCrossentropy(), metrics=['accuracy'])
model.compile(optimizer=optimizer,loss='categorical_crossentropy',metrics=METRICS)

# %% [markdown]
# ### v. Training the Model

# %%
history = model.fit(train_generator,
                    steps_per_epoch=15,
                    validation_data=validation_generator,
                    validation_steps=2,
                    epochs=30,verbose = 2,
                    callbacks=[reduce_lr])
# Out:
# Epoch 1/30
# WARNING:tensorflow:From /usr/local/lib/python3.9/dist-packages/tensorflow/python/autograph/pyct/static_analysis/liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089
# 15/15 - 385s - loss: 0.5817 - accuracy: 0.6904 - precision: 0.6904 - recall: 0.6904 - auc: 0.7591 - f1_Score: 0.6890 - val_loss: 0.6827 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.6025 - val_f1_Score: 0.3333 - lr: 0.0010 - 385s/epoch - 26s/step
# Epoch 2/30
# 15/15 - 191s - loss: 0.3061 - accuracy: 0.8687 - precision: 0.8687 - recall: 0.8687 - auc: 0.9434 - f1_Score: 0.8687 - val_loss: 1.1689 - val_accuracy: 0.4219 - val_precision: 0.4219 - val_recall: 0.4219 - val_auc: 0.4395 - val_f1_Score: 0.2967 - lr: 0.0010 - 191s/epoch - 13s/step
# Epoch 3/30
# 15/15 - 189s - loss: 0.2959 - accuracy: 0.8917 - precision: 0.8917 - recall: 0.8917 - auc: 0.9476 - f1_Score: 0.8906 - val_loss: 1.2944 - val_accuracy: 0.6094 - val_precision: 0.6094 - val_recall: 0.6094 - val_auc: 0.7043 - val_f1_Score: 0.5867 - lr: 0.0010 - 189s/epoch - 13s/step
# Epoch 4/30
# 15/15 - 132s - loss: 0.2184 - accuracy: 0.9250 - precision: 0.9250 - recall: 0.9250 - auc: 0.9695 - f1_Score: 0.9249 - val_loss: 2.2287 - val_accuracy: 0.6094 - val_precision: 0.6094 - val_recall: 0.6094 - val_auc: 0.6528 - val_f1_Score: 0.5797 - lr: 0.0010 - 132s/epoch - 9s/step
# Epoch 5/30
# 15/15 - 126s - loss: 0.2615 - accuracy: 0.9208 - precision: 0.9208 - recall: 0.9208 - auc: 0.9624 - f1_Score: 0.9208 - val_loss: 0.2910 - val_accuracy: 0.8438 - val_precision: 0.8438 - val_recall: 0.8438 - val_auc: 0.9502 - val_f1_Score: 0.8359 - lr: 0.0010 - 126s/epoch - 8s/step
# Epoch 6/30
# 15/15 - 113s - loss: 0.1603 - accuracy: 0.9396 - precision: 0.9396 - recall: 0.9396 - auc: 0.9828 - f1_Score: 0.9395 - val_loss: 0.8458 - val_accuracy: 0.7188 - val_precision: 0.7188 - val_recall: 0.7188 - val_auc: 0.7668 - val_f1_Score: 0.7176 - lr: 0.0010 - 113s/epoch - 8s/step
# Epoch 7/30
# 15/15 - 107s - loss: 0.1757 - accuracy: 0.9396 - precision: 0.9396 - recall: 0.9396 - auc: 0.9785 - f1_Score: 0.9395 - val_loss: 0.5176 - val_accuracy: 0.8125 - val_precision: 0.8125 - val_recall: 0.8125 - val_auc: 0.8835 - val_f1_Score: 0.8095 - lr: 0.0010 - 107s/epoch - 7s/step
# Epoch 8/30
# 15/15 - 100s - loss: 0.1907 - accuracy: 0.9354 - precision: 0.9354 - recall: 0.9354 - auc: 0.9777 - f1_Score: 0.9354 - val_loss: 0.4086 - val_accuracy: 0.7812 - val_precision: 0.7812 - val_recall: 0.7812 - val_auc: 0.8970 - val_f1_Score: 0.7778 - lr: 0.0010 - 100s/epoch - 7s/step
# Epoch 9/30
# 15/15 - 88s - loss: 0.1440 - accuracy: 0.9399 - precision: 0.9399 - recall: 0.9399 - auc: 0.9880 - f1_Score: 0.9398 - val_loss: 0.2762 - val_accuracy: 0.8750 - val_precision: 0.8750 - val_recall: 0.8750 - val_auc: 0.9592 - val_f1_Score: 0.8719 - lr: 0.0010 - 88s/epoch - 6s/step
# Epoch 10/30
# 15/15 - 82s - loss: 0.1639 - accuracy: 0.9417 - precision: 0.9417 - recall: 0.9417 - auc: 0.9831 - f1_Score: 0.9416 - val_loss: 0.6007 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - val_auc: 0.8879 - val_f1_Score: 0.7333 - lr: 0.0010 - 82s/epoch - 5s/step
# Epoch 11/30
# 15/15 - 76s - loss: 0.1321 - accuracy: 0.9458 - precision: 0.9458 - recall: 0.9458 - auc: 0.9871 - f1_Score: 0.9458 - val_loss: 0.6461 - val_accuracy: 0.7656 - val_precision: 0.7656 - val_recall: 0.7656 - val_auc: 0.8862 - val_f1_Score: 0.7585 - lr: 0.0010 - 76s/epoch - 5s/step
# Epoch 12/30
# 15/15 - 60s - loss: 0.1028 - accuracy: 0.9555 - precision: 0.9555 - recall: 0.9555 - auc: 0.9940 - f1_Score: 0.9553 - val_loss: 0.0721 - val_accuracy: 0.9844 - val_precision: 0.9844 - val_recall: 0.9844 - val_auc: 0.9978 - val_f1_Score: 0.9844 - lr: 0.0010 - 60s/epoch - 4s/step
# Epoch 13/30
# 15/15 - 62s - loss: 0.0956 - accuracy: 0.9644 - precision: 0.9644 - recall: 0.9644 - auc: 0.9946 - f1_Score: 0.9642 - val_loss: 0.1351 - val_accuracy: 0.9688 - val_precision: 0.9688 - val_recall: 0.9688 - val_auc: 0.9890 - val_f1_Score: 0.9688 - lr: 0.0010 - 62s/epoch - 4s/step
# Epoch 14/30
# 15/15 - 72s - loss: 0.1358 - accuracy: 0.9563 - precision: 0.9563 - recall: 0.9563 - auc: 0.9856 - f1_Score: 0.9561 - val_loss: 0.0637 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000 - val_f1_Score: 1.0000 - lr: 0.0010 - 72s/epoch - 5s/step
# Epoch 15/30
# 15/15 - 57s - loss: 0.1403 - accuracy: 0.9312 - precision: 0.9312 - recall: 0.9312 - auc: 0.9884 - f1_Score: 0.9312 - val_loss: 0.6022 - val_accuracy: 0.6719 - val_precision: 0.6719 - val_recall: 0.6719 - val_auc: 0.8354 - val_f1_Score: 0.6470 - lr: 0.0010 - 57s/epoch - 4s/step
# Epoch 16/30
# 15/15 - 52s - loss: 0.1027 - accuracy: 0.9646 - precision: 0.9646 - recall: 0.9646 - auc: 0.9937 - f1_Score: 0.9646 - val_loss: 0.2191 - val_accuracy: 0.9219 - val_precision: 0.9219 - val_recall: 0.9219 - val_auc: 0.9729 - val_f1_Score: 0.9159 - lr: 0.0010 - 52s/epoch - 3s/step
# Epoch 17/30
# 15/15 - 53s - loss: 0.1093 - accuracy: 0.9666 - precision: 0.9666 - recall: 0.9666 - auc: 0.9896 - f1_Score: 0.9664 - val_loss: 0.0915 - val_accuracy: 0.9688 - val_precision: 0.9688 - val_recall: 0.9688 - val_auc: 0.9973 - val_f1_Score: 0.9687 - lr: 0.0010 - 53s/epoch - 4s/step
# Epoch 18/30
# 15/15 - 54s - loss: 0.0519 - accuracy: 0.9755 - precision: 0.9755 - recall: 0.9755 - auc: 0.9989 - f1_Score: 0.9755 - val_loss: 0.0574 - val_accuracy: 0.9844 - val_precision: 0.9844 - val_recall: 0.9844 - val_auc: 0.9998 - val_f1_Score: 0.9835 - lr: 0.0010 - 54s/epoch - 4s/step
# Epoch 19/30
# 15/15 - 46s - loss: 0.0846 - accuracy: 0.9800 - precision: 0.9800 - recall: 0.9800 - auc: 0.9932 - f1_Score: 0.9799 - val_loss: 0.0049 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000 - val_f1_Score: 1.0000 - lr: 0.0010 - 46s/epoch - 3s/step
# Epoch 20/30
# 15/15 - 47s - loss: 0.0927 - accuracy: 0.9625 - precision: 0.9625 - recall: 0.9625 - auc: 0.9949 - f1_Score: 0.9622 - val_loss: 0.1570 - val_accuracy: 0.9062 - val_precision: 0.9062 - val_recall: 0.9062 - val_auc: 0.9849 - val_f1_Score: 0.9059 - lr: 0.0010 - 47s/epoch - 3s/step
# Epoch 21/30
# 15/15 - 43s - loss: 0.0771 - accuracy: 0.9688 - precision: 0.9688 - recall: 0.9688 - auc: 0.9966 - f1_Score: 0.9687 - val_loss: 0.2348 - val_accuracy: 0.8594 - val_precision: 0.8594 - val_recall: 0.8594 - val_auc: 0.9587 - val_f1_Score: 0.8551 - lr: 0.0010 - 43s/epoch - 3s/step
# Epoch 22/30
# 15/15 - 45s - loss: 0.0754 - accuracy: 0.9708 - precision: 0.9708 - recall: 0.9708 - auc: 0.9965 - f1_Score: 0.9708 - val_loss: 0.0749 - val_accuracy: 0.9688 - val_precision: 0.9688 - val_recall: 0.9688 - val_auc: 0.9966 - val_f1_Score: 0.9686 - lr: 0.0010 - 45s/epoch - 3s/step
# Epoch 23/30
# 15/15 - 43s - loss: 0.0396 - accuracy: 0.9812 - precision: 0.9812 - recall: 0.9812 - auc: 0.9992 - f1_Score: 0.9812 - val_loss: 0.0357 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000 - val_f1_Score: 1.0000 - lr: 0.0010 - 43s/epoch - 3s/step
# Epoch 24/30
# 15/15 - 45s - loss: 0.0665 - accuracy: 0.9729 - precision: 0.9729 - recall: 0.9729 - auc: 0.9976 - f1_Score: 0.9729 - val_loss: 0.1485 - val_accuracy: 0.9688 - val_precision: 0.9688 - val_recall: 0.9688 - val_auc: 0.9788 - val_f1_Score: 0.9685 - lr: 0.0010 - 45s/epoch - 3s/step
# Epoch 25/30
# 15/15 - 42s - loss: 0.0604 - accuracy: 0.9800 - precision: 0.9800 - recall: 0.9800 - auc: 0.9962 - f1_Score: 0.9800 - val_loss: 0.0931 - val_accuracy: 0.9531 - val_precision: 0.9531 - val_recall: 0.9531 - val_auc: 0.9941 - val_f1_Score: 0.9517 - lr: 3.1623e-04 - 42s/epoch - 3s/step
# Epoch 26/30
# 15/15 - 40s - loss: 0.0684 - accuracy: 0.9771 - precision: 0.9771 - recall: 0.9771 - auc: 0.9973 - f1_Score: 0.9771 - val_loss: 0.1674 - val_accuracy: 0.9375 - val_precision: 0.9375 - val_recall: 0.9375 - val_auc: 0.9856 - val_f1_Score: 0.9369 - lr: 3.1623e-04 - 40s/epoch - 3s/step
# Epoch 27/30
# 15/15 - 38s - loss: 0.0418 - accuracy: 0.9833 - precision: 0.9833 - recall: 0.9833 - auc: 0.9990 - f1_Score: 0.9833 - val_loss: 0.2357 - val_accuracy: 0.9219 - val_precision: 0.9219 - val_recall: 0.9219 - val_auc: 0.9707 - val_f1_Score: 0.9173 - lr: 3.1623e-04 - 38s/epoch - 3s/step
# Epoch 28/30
# 15/15 - 41s - loss: 0.0351 - accuracy: 0.9889 - precision: 0.9889 - recall: 0.9889 - auc: 0.9991 - f1_Score: 0.9889 - val_loss: 0.0249 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000 - val_f1_Score: 1.0000 - lr: 3.1623e-04 - 41s/epoch - 3s/step
# Epoch 29/30
# 15/15 - 35s - loss: 0.0267 - accuracy: 0.9917 - precision: 0.9917 - recall: 0.9917 - auc: 0.9997 - f1_Score: 0.9917 - val_loss: 0.0416 - val_accuracy: 0.9844 - val_precision: 0.9844 - val_recall: 0.9844 - val_auc: 0.9988 - val_f1_Score: 0.9841 - lr: 3.1623e-04 - 35s/epoch - 2s/step
# Epoch 30/30
# 15/15 - 41s - loss: 0.0176 - accuracy: 0.9933 - precision: 0.9933 - recall: 0.9933 - auc: 0.9999 - f1_Score: 0.9933 - val_loss: 0.1334 - val_accuracy: 0.9375 - val_precision: 0.9375 - val_recall: 0.9375 - val_auc: 0.9939 - val_f1_Score: 0.9369 - lr: 1.0000e-04 - 41s/epoch - 3s/step

# %%
from keras.preprocessing import image
path="/content/drive/MyDrive/COVID-19_Radiography_Dataset/Val/Covid/COVID-2619.png"
img=image.load_img(path,target_size=(256,256))
img=image.img_to_array(img)/255

img=np.array([img])

img.shape
(model.predict(img) > 0.5).astype("int32")

# %%
model.save("model.h5")

# %% [markdown]
# ## **5. Plotting the Model Metrics**
# ### i. Plotting training and validation accuracy, loss and learning rate

# %%
plt.figure( figsize = (15,8)) 
    
plt.subplot(221)  
# Accuracy 
plt.plot(model.history.history['accuracy'])
plt.plot(model.history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Training set', 'Validation set'], loc='upper left')
plt.show()


# Loss
plt.figure( figsize = (15,8)) 
plt.subplot(222)  
plt.plot(model.history.history['loss'])
plt.plot(model.history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Training set', 'Validation set'], loc='upper left')
plt.show()

# %%
train_accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

train_loss = history.history['loss']
val_loss = history.history['val_loss']

learning_rate = history.history['lr']


ans = history.history['val_recall']
ans
# Out:
# [0.5,
#  0.421875,
#  0.609375,
#  0.609375,
#  0.84375,
#  0.71875,
#  0.8125,
#  0.78125,
#  0.875,
#  0.75,
#  0.765625,
#  0.984375,
#  0.96875,
#  1.0,
#  0.671875,
#  0.921875,
#  0.96875,
#  0.984375,
#  1.0,
#  0.90625,
#  0.859375,
#  0.96875,
#  1.0,
#  0.96875,
#  0.953125,
#  0.9375,
#  0.921875,
#  1.0,
#  0.984375,
#  0.9375]

# %%
fig, ax = plt.subplots(nrows=3, ncols=1, figsize=(12, 10))

ax[0].set_title('Training Accuracy vs. Epochs')
ax[0].plot(train_accuracy, 'o-', label='Train Accuracy')
ax[0].plot(val_accuracy, 'o-', label='Validation Accuracy')
ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Accuracy')
ax[0].legend(loc='best')

ax[1].set_title('Training/Validation Loss vs. Epochs')
ax[1].plot(train_loss, 'o-', label='Train Loss')
ax[1].plot(val_loss, 'o-', label='Validation Loss')
ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Loss')
ax[1].legend(loc='best')

ax[2].set_title('Learning Rate vs. Epochs')
ax[2].plot(learning_rate, 'o-', label='Learning Rate')
ax[2].set_xlabel('Epochs')
ax[2].set_ylabel('Loss')
ax[2].legend(loc='best')

plt.tight_layout()
plt.show()

# %%
def Train_Val_Plot(acc,val_acc,loss,val_loss,auc,val_auc,precision,val_precision,f1_Score,val_f1_Score):
    
    fig, (ax1, ax2,ax3,ax4,ax5) = plt.subplots(1,5, figsize= (20,5))
    fig.suptitle(" MODEL'S METRICS VISUALIZATION ")

    ax1.plot(range(1, len(acc) + 1), acc)
    ax1.plot(range(1, len(val_acc) + 1), val_acc)
    ax1.set_title('History of Accuracy')
    ax1.set_xlabel('Epochs')
    ax1.set_ylabel('Accuracy')
    ax1.legend(['training', 'validation'])


    ax2.plot(range(1, len(loss) + 1), loss)
    ax2.plot(range(1, len(val_loss) + 1), val_loss)
    ax2.set_title('History of Loss')
    ax2.set_xlabel('Epochs')
    ax2.set_ylabel('Loss')
    ax2.legend(['training', 'validation'])
    
    ax3.plot(range(1, len(auc) + 1), auc)
    ax3.plot(range(1, len(val_auc) + 1), val_auc)
    ax3.set_title('History of AUC')
    ax3.set_xlabel('Epochs')
    ax3.set_ylabel('AUC')
    ax3.legend(['training', 'validation'])
    
    ax4.plot(range(1, len(precision) + 1), precision)
    ax4.plot(range(1, len(val_precision) + 1), val_precision)
    ax4.set_title('History of Precision')
    ax4.set_xlabel('Epochs')
    ax4.set_ylabel('Precision')
    ax4.legend(['training', 'validation'])
    
    ax5.plot(range(1, len(f1_Score) + 1), f1_Score)
    ax5.plot(range(1, len(val_f1_Score) + 1), val_f1_Score)
    ax5.set_title('History of F1-score')
    ax5.set_xlabel('Epochs')
    ax5.set_ylabel('F1 score')
    ax5.legend(['training', 'validation'])


    plt.show()
    
import numpy as np
# f1_s= np.mean(history.history['f1_Score'])
# val_f1_s= np.mean(history.history['val_f1_Score'])
Train_Val_Plot(history.history['accuracy'],history.history['val_accuracy'],
               history.history['loss'],history.history['val_loss'],
               history.history['auc'],history.history['val_auc'],
               history.history['precision'],history.history['val_precision']
              #  f1_s,val_f1_s

                , history.history['f1_Score'],history.history['val_f1_Score']
              )

# %% [markdown]
# ## 6. Testing the Model on Test Set
# Testing the model on the validation dataset because a seperate dataset for testing is not available.

# %%
test_dataset = '/content/drive/MyDrive/FYP/test'

# %%
test_datagen = ImageDataGenerator(rescale=1.0/255)

test_generator = test_datagen.flow_from_directory(test_dataset,
                                                 shuffle=False,
                                                 batch_size=BATCH_SIZE,
                                                 target_size = (IMG_WIDTH, IMG_HEIGHT),
                                                 class_mode='categorical')
# Out:
# Found 3000 images belonging to 2 classes.

# %% [markdown]
# ## 7. Model Prediction on the Test Dataset

# %%
predictions = model.predict(test_generator)
# Out:
# 94/94 [==============================] - 916s 10s/step

# %%
fig, ax = plt.subplots(nrows=2, ncols=5, figsize=(12, 10))
idx = 0

for i in range(2):
    for j in range(5):
        predicted_label = labels[np.argmax(predictions[idx])]
        ax[i, j].set_title(f"{predicted_label}")
        ax[i, j].imshow(test_generator[0][0][idx])
        ax[i, j].axis("off")
        idx += 1

plt.tight_layout()
plt.suptitle("Test Dataset Predictions", fontsize=20)
plt.show()

# %%
train_loss, train_accuracy, train_precision, train_recall, train_auc, train_F1_Score = model.evaluate(train_generator, batch_size=BATCH_SIZE)
# Out:
# 95/95 [==============================] - 51s 529ms/step - loss: 0.0095 - accuracy: 0.9977 - precision: 0.9977 - recall: 0.9977 - auc: 1.0000 - f1_Score: 0.9977

# %%
print(f"Train Loss:     {train_loss}")
print(f"Train Accuracy: {train_accuracy}")
print(f"Train Precision: {train_precision}")
print(f"Train Recall: {train_recall}")
print(f"Train AUC: {train_auc}")
print(f"Train F1_Score: {np.mean(train_F1_Score)}")
# Out:
# Train Loss:     0.009512538090348244
# Train Accuracy: 0.9976736307144165
# Train Precision: 0.9976736307144165
# Train Recall: 0.9976736307144165
# Train AUC: 0.9999656081199646
# Train F1_Score: 0.9976736307144165

# %%
test_loss, test_accuracy, test_precision, test_recall, test_auc, test_F1_Score = model.evaluate(test_generator, batch_size=BATCH_SIZE)

# %%
print(f"Test Loss:     {test_loss}")
print(f"Test Accuracy: {test_accuracy}")
print(f"Test Precision: {test_precision}")
print(f"Test Recall: {test_recall}")
print(f"Test AUC: {test_auc}")
print(f"Test F1_Score: {np.mean(test_F1_Score)}")

# %% [markdown]
# ## **8. Plotting the Classification Metrics**
# ### i. Confusion Matrix

# %%
y_pred = np.argmax(predictions, axis=1)
y_true = test_generator.classes

# %%
cf_mtx = confusion_matrix(y_true, y_pred)

group_counts = ["{0:0.0f}".format(value) for value in cf_mtx.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in cf_mtx.flatten()/np.sum(cf_mtx)]
box_labels = [f"{v1}\n({v2})" for v1, v2 in zip(group_counts, group_percentages)]
box_labels = np.asarray(box_labels).reshape(2, 2)

plt.figure(figsize = (12, 10))
sns.heatmap(cf_mtx, xticklabels=labels.values(), yticklabels=labels.values(),
           cmap="YlGnBu", fmt="", annot=box_labels)
plt.xlabel('Predicted Classes')
plt.ylabel('True Classes')
plt.show()

# %%
print(classification_report(y_true, y_pred, target_names=labels.values()))

# %%
A=history.history['accuracy']
A_v=history.history['val_accuracy']
L=history.history['loss']
L_v=history.history['val_loss']
Auc=history.history['auc']
Auc_v=history.history['val_auc']
P=history.history['precision']
P_v=history.history['val_precision']
F1=history.history['f1_Score']
F1_v=history.history['val_f1_Score']
import pandas as pd
data_to_submit = pd.DataFrame({
    'accuracy':A,
    'val_accuracy':A_v,
    'loss': L,
    'val_loss': L_v,
    'auc':Auc,
    'val_auc':Auc_v,
    'precision':P,
    'val_precision':P_v,
    'f1_score':F1,
    'val_f1_score':F1_v
})
data_to_submit.to_csv('EffectiveNetV2L.csv', index = False)
