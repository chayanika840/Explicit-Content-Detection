# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## **Importing necessary packages**

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import cv2
import os

import warnings
warnings.filterwarnings('ignore')

from sklearn.metrics import confusion_matrix, classification_report

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation, BatchNormalization, Conv2D, Dense, Dropout, Flatten, MaxPool2D,MaxPooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping

# %% [markdown]
# ## **2. Load the Image Training and Validation Datasets**
#
# ### i. Get the Image Dataset Paths

# %%
train_dataset_path = '/content/drive/MyDrive/FYP/train'
validation_dataset_path = '/content/drive/MyDrive/FYP/val'

# %% [markdown]
# ### ii. Load Image Datasets and Apply Augmentations
# Since the images present in the datasets are 150x150px in size, the image height and width are taken as 150, 150 respectively. The batch size value can be changed if required.

# %%
IMG_WIDTH = 150
IMG_HEIGHT = 150
BATCH_SIZE = 16

# %% [markdown]
# Loading the training dataset and applying augmentations on it.

# %%
train_datagen = ImageDataGenerator(rescale=1.0/255,
                                  zoom_range=0.2,
                                  width_shift_range=0.2,
                                  height_shift_range=0.2,
                                  fill_mode='nearest')
train_generator = train_datagen.flow_from_directory(train_dataset_path,
                                                   target_size=(IMG_WIDTH, IMG_HEIGHT),
                                                   batch_size=BATCH_SIZE,
                                                   class_mode='categorical',
                                                   shuffle=True)
# Out:
# Found 3009 images belonging to 2 classes.

# %% [markdown]
# Loading the validation dataset.

# %%
validation_datagen = ImageDataGenerator(rescale=1.0/255)
validation_generator = validation_datagen.flow_from_directory(validation_dataset_path,
                                                             target_size=(IMG_WIDTH, IMG_HEIGHT),
                                                             batch_size=BATCH_SIZE,
                                                             class_mode='categorical',
                                                             shuffle=True)
# Out:
# Found 3019 images belonging to 2 classes.

# %% [markdown]
# ### iii. Get the Label Mappings
# The labels dictionary is made in order to retrive the class names against the label indices used for training the model

# %%
labels = {value: key for key, value in train_generator.class_indices.items()}

print("Label Mappings for classes present in the training and validation datasets\n")
for key, value in labels.items():
    print(f"{key} : {value}")
# Out:
# Label Mappings for classes present in the training and validation datasets
#
# 0 : Nonnude
# 1 : Nude

# %% [markdown]
# ## **3. Plotting Sample Training Image**s

# %%
fig, ax = plt.subplots(nrows=2, ncols=5, figsize=(15, 12))
idx = 0

for i in range(2):
    for j in range(5):
        label = labels[np.argmax(train_generator[0][1][idx])]
        ax[i, j].set_title(f"{label}")
        ax[i, j].imshow(train_generator[0][0][idx][:, :, :])
        ax[i, j].axis("off")
        idx += 1

plt.tight_layout()
plt.suptitle("Sample Training Images", fontsize=21)
plt.show()

# %% [markdown]
# ## **4. Training a EfficientNetV2M Model**
#
#
# ### i. Create a EfficientNetV2M Model

# %%
base_model = tf.keras.applications.EfficientNetV2M(
                     include_top=False,
                     weights='imagenet',
                     input_shape=(150,150,3),
                     include_preprocessing=True
                     )

base_model.trainable=True

from sklearn.ensemble import VotingClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
import tensorflow as tf

# Define the models to use in the ensemble
model1 = tf.keras.models.Sequential()
# ... define architecture and compile for model1

model2 = tf.keras.models.Sequential()
# ... define architecture and compile for model2

model3 = tf.keras.models.Sequential()
# ... define architecture and compile for model3

# Create an ensemble model that uses majority voting
ensemble = VotingClassifier(estimators=[('model1', model1), ('model2', model2), ('model3', model3)], voting='soft')

# Train the ensemble model on the data
#x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)
#ensemble.fit(X_train, y_train)

# Evaluate the ensemble model on the test data
#y_pred = ensemble.predict(X_test)
#accuracy = accuracy_score(y_test, y_pred)
#print('Accuracy:', accuracy)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/efficientnet_v2/efficientnetv2-m_notop.h5
# 214201816/214201816 [==============================] - 1s 0us/step

# %%
model = tf.keras.Sequential([
        base_model,  
        tf.keras.layers.BatchNormalization(renorm=True),
        tf.keras.layers.GlobalAveragePooling2D(),
        tf.keras.layers.Dense(512, activation='relu'),
        tf.keras.layers.Dense(256, activation='relu'),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.Dense(128, activation='relu'),
        tf.keras.layers.Dense(2, activation='softmax')
    ])

# %%
print(model.summary())
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  efficientnetv2-m (Functiona  (None, 5, 5, 1280)       53150388
#  l)
#
#  batch_normalization (BatchN  (None, 5, 5, 1280)       8960
#  ormalization)
#
#  global_average_pooling2d (G  (None, 1280)             0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 512)               655872
#
#  dense_1 (Dense)             (None, 256)               131328
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_2 (Dense)             (None, 128)               32896
#
#  dense_3 (Dense)             (None, 2)                 258
#
# =================================================================
# Total params: 53,979,702
# Trainable params: 53,681,270
# Non-trainable params: 298,432
# _________________________________________________________________
# None

# %% [markdown]
# ### ii. Defining Callbacks
# A callback is an object that can perform actions at various stages of training (e.g. at the start or end of an epoch, before or after a single batch, etc)
#
# a. Reduce Learning Rate on Plateau
# Is used to reduce the learning rate when a metric has stopped improving.

# %%
# !pip install tensorflow_addons
import tensorflow_addons as tfa
METRICS = [
      # tf.keras.metrics.BinaryAccuracy(name='binary_accuracy'),
      # tf.keras.metrics.Accuracy(name='accuracy'),
      tf.keras.metrics.CategoricalAccuracy(name='accuracy'),
      tf.keras.metrics.Precision(name='precision'),
      tf.keras.metrics.Recall(name='recall'),  
      tf.keras.metrics.AUC(name='auc'),
      # tf.keras.metrics.F1Score(name='F1'),
      tfa.metrics.F1Score(num_classes= 2,name="f1_Score")

    
]
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tensorflow_addons
#   Downloading tensorflow_addons-0.19.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 15.0 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from tensorflow_addons) (23.0)
# Requirement already satisfied: typeguard>=2.7 in /usr/local/lib/python3.8/dist-packages (from tensorflow_addons) (2.7.1)
# Installing collected packages: tensorflow_addons
# Successfully installed tensorflow_addons-0.19.0

# %%
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=np.sqrt(0.1), patience=5)
# early = tf.keras.callbacks.EarlyStopping( patience=10,
#                                           min_delta=0.001,
#                                           restore_best_weights=True)

# %% [markdown]
# ### iii. Defining the Optimizer

# %%
optimizer = tf.optimizers.Adamax(learning_rate=0.001)

# %% [markdown]
# ### iv. Compile the Model

# %%
# cnn_model.compile(optimizer=optimizer, loss=CategoricalCrossentropy(), metrics=['accuracy'])
model.compile(optimizer=optimizer,loss='categorical_crossentropy',metrics=METRICS)

# %% [markdown]
# ### v. Training the Model

# %%
history = model.fit(train_generator,
                    steps_per_epoch=15,
                    validation_data=validation_generator,
                    validation_steps=2,
                    epochs=30,verbose = 2,
                    callbacks=[reduce_lr])
# Out:
# Epoch 1/30
# 15/15 - 122s - loss: 0.5474 - accuracy: 0.6625 - precision: 0.6625 - recall: 0.6625 - auc: 0.7717 - f1_Score: 0.6588 - val_loss: 0.6223 - val_accuracy: 0.8125 - val_precision: 0.8125 - val_recall: 0.8125 - val_auc: 0.7598 - val_f1_Score: 0.4483 - lr: 0.0010 - 122s/epoch - 8s/step
# Epoch 2/30
# 15/15 - 48s - loss: 0.4972 - accuracy: 0.7875 - precision: 0.7875 - recall: 0.7875 - auc: 0.8677 - f1_Score: 0.7872 - val_loss: 0.7532 - val_accuracy: 0.4688 - val_precision: 0.4688 - val_recall: 0.4688 - val_auc: 0.4775 - val_f1_Score: 0.3191 - lr: 0.0010 - 48s/epoch - 3s/step
# Epoch 3/30
# 15/15 - 39s - loss: 0.4196 - accuracy: 0.8208 - precision: 0.8208 - recall: 0.8208 - auc: 0.8921 - f1_Score: 0.8208 - val_loss: 1.0605 - val_accuracy: 0.4688 - val_precision: 0.4688 - val_recall: 0.4688 - val_auc: 0.5859 - val_f1_Score: 0.3976 - lr: 0.0010 - 39s/epoch - 3s/step
# Epoch 4/30
# 15/15 - 39s - loss: 0.3987 - accuracy: 0.8356 - precision: 0.8356 - recall: 0.8356 - auc: 0.9112 - f1_Score: 0.8349 - val_loss: 0.8198 - val_accuracy: 0.6562 - val_precision: 0.6562 - val_recall: 0.6562 - val_auc: 0.7988 - val_f1_Score: 0.6102 - lr: 0.0010 - 39s/epoch - 3s/step
# Epoch 5/30
# 15/15 - 42s - loss: 0.2965 - accuracy: 0.8708 - precision: 0.8708 - recall: 0.8708 - auc: 0.9467 - f1_Score: 0.8702 - val_loss: 1.3400 - val_accuracy: 0.6250 - val_precision: 0.6250 - val_recall: 0.6250 - val_auc: 0.7266 - val_f1_Score: 0.6000 - lr: 0.0010 - 42s/epoch - 3s/step
# Epoch 6/30
# 15/15 - 37s - loss: 0.2350 - accuracy: 0.9208 - precision: 0.9208 - recall: 0.9208 - auc: 0.9630 - f1_Score: 0.9208 - val_loss: 0.2499 - val_accuracy: 0.8750 - val_precision: 0.8750 - val_recall: 0.8750 - val_auc: 0.9590 - val_f1_Score: 0.8615 - lr: 0.0010 - 37s/epoch - 2s/step
# Epoch 7/30
# 15/15 - 37s - loss: 0.2903 - accuracy: 0.8750 - precision: 0.8750 - recall: 0.8750 - auc: 0.9509 - f1_Score: 0.8749 - val_loss: 0.3910 - val_accuracy: 0.8438 - val_precision: 0.8438 - val_recall: 0.8438 - val_auc: 0.9141 - val_f1_Score: 0.8424 - lr: 0.0010 - 37s/epoch - 2s/step
# Epoch 8/30
# 15/15 - 30s - loss: 0.3218 - accuracy: 0.8792 - precision: 0.8792 - recall: 0.8792 - auc: 0.9400 - f1_Score: 0.8791 - val_loss: 0.5355 - val_accuracy: 0.5938 - val_precision: 0.5938 - val_recall: 0.5938 - val_auc: 0.8096 - val_f1_Score: 0.3725 - lr: 0.0010 - 30s/epoch - 2s/step
# Epoch 9/30
# 15/15 - 30s - loss: 0.2481 - accuracy: 0.9083 - precision: 0.9083 - recall: 0.9083 - auc: 0.9624 - f1_Score: 0.9082 - val_loss: 0.6140 - val_accuracy: 0.6875 - val_precision: 0.6875 - val_recall: 0.6875 - val_auc: 0.7197 - val_f1_Score: 0.6863 - lr: 0.0010 - 30s/epoch - 2s/step
# Epoch 10/30
# 15/15 - 30s - loss: 0.1857 - accuracy: 0.9375 - precision: 0.9375 - recall: 0.9375 - auc: 0.9810 - f1_Score: 0.9371 - val_loss: 0.2750 - val_accuracy: 0.8438 - val_precision: 0.8438 - val_recall: 0.8438 - val_auc: 0.9648 - val_f1_Score: 0.8398 - lr: 0.0010 - 30s/epoch - 2s/step
# Epoch 11/30
# 15/15 - 33s - loss: 0.2994 - accuracy: 0.8844 - precision: 0.8844 - recall: 0.8844 - auc: 0.9531 - f1_Score: 0.8841 - val_loss: 0.3109 - val_accuracy: 0.9062 - val_precision: 0.9062 - val_recall: 0.9062 - val_auc: 0.9526 - val_f1_Score: 0.9015 - lr: 0.0010 - 33s/epoch - 2s/step
# Epoch 12/30
# 15/15 - 28s - loss: 0.3388 - accuracy: 0.8833 - precision: 0.8833 - recall: 0.8833 - auc: 0.9401 - f1_Score: 0.8833 - val_loss: 0.3937 - val_accuracy: 0.9375 - val_precision: 0.9375 - val_recall: 0.9375 - val_auc: 0.9160 - val_f1_Score: 0.9375 - lr: 3.1623e-04 - 28s/epoch - 2s/step
# Epoch 13/30
# 15/15 - 29s - loss: 0.2423 - accuracy: 0.9000 - precision: 0.9000 - recall: 0.9000 - auc: 0.9638 - f1_Score: 0.8998 - val_loss: 0.3494 - val_accuracy: 0.9375 - val_precision: 0.9375 - val_recall: 0.9375 - val_auc: 0.9434 - val_f1_Score: 0.9373 - lr: 3.1623e-04 - 29s/epoch - 2s/step
# Epoch 14/30
# 15/15 - 26s - loss: 0.2079 - accuracy: 0.9208 - precision: 0.9208 - recall: 0.9208 - auc: 0.9737 - f1_Score: 0.9206 - val_loss: 0.1982 - val_accuracy: 0.9375 - val_precision: 0.9375 - val_recall: 0.9375 - val_auc: 0.9746 - val_f1_Score: 0.9373 - lr: 3.1623e-04 - 26s/epoch - 2s/step
# Epoch 15/30
# 15/15 - 25s - loss: 0.2874 - accuracy: 0.9042 - precision: 0.9042 - recall: 0.9042 - auc: 0.9565 - f1_Score: 0.9041 - val_loss: 0.0725 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000 - val_f1_Score: 1.0000 - lr: 3.1623e-04 - 25s/epoch - 2s/step
# Epoch 16/30
# 15/15 - 25s - loss: 0.1957 - accuracy: 0.9083 - precision: 0.9083 - recall: 0.9083 - auc: 0.9776 - f1_Score: 0.9083 - val_loss: 0.5555 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - val_auc: 0.8828 - val_f1_Score: 0.7333 - lr: 3.1623e-04 - 25s/epoch - 2s/step
# Epoch 17/30
# 15/15 - 22s - loss: 0.1742 - accuracy: 0.9458 - precision: 0.9458 - recall: 0.9458 - auc: 0.9804 - f1_Score: 0.9458 - val_loss: 0.9576 - val_accuracy: 0.5938 - val_precision: 0.5938 - val_recall: 0.5938 - val_auc: 0.7051 - val_f1_Score: 0.5934 - lr: 3.1623e-04 - 22s/epoch - 1s/step
# Epoch 18/30
# 15/15 - 19s - loss: 0.1881 - accuracy: 0.9250 - precision: 0.9250 - recall: 0.9250 - auc: 0.9786 - f1_Score: 0.9248 - val_loss: 0.0808 - val_accuracy: 0.9688 - val_precision: 0.9688 - val_recall: 0.9688 - val_auc: 0.9990 - val_f1_Score: 0.9687 - lr: 3.1623e-04 - 19s/epoch - 1s/step
# Epoch 19/30
# 15/15 - 19s - loss: 0.1694 - accuracy: 0.9333 - precision: 0.9333 - recall: 0.9333 - auc: 0.9811 - f1_Score: 0.9329 - val_loss: 0.0989 - val_accuracy: 0.9375 - val_precision: 0.9375 - val_recall: 0.9375 - val_auc: 0.9932 - val_f1_Score: 0.9373 - lr: 3.1623e-04 - 19s/epoch - 1s/step
# Epoch 20/30
# 15/15 - 15s - loss: 0.2102 - accuracy: 0.9208 - precision: 0.9208 - recall: 0.9208 - auc: 0.9727 - f1_Score: 0.9208 - val_loss: 0.0764 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000 - val_f1_Score: 1.0000 - lr: 3.1623e-04 - 15s/epoch - 1s/step
# Epoch 21/30
# 15/15 - 19s - loss: 0.1180 - accuracy: 0.9583 - precision: 0.9583 - recall: 0.9583 - auc: 0.9928 - f1_Score: 0.9583 - val_loss: 0.1452 - val_accuracy: 0.9062 - val_precision: 0.9062 - val_recall: 0.9062 - val_auc: 0.9873 - val_f1_Score: 0.9054 - lr: 1.0000e-04 - 19s/epoch - 1s/step
# Epoch 22/30
# 15/15 - 20s - loss: 0.1722 - accuracy: 0.9333 - precision: 0.9333 - recall: 0.9333 - auc: 0.9817 - f1_Score: 0.9333 - val_loss: 0.1531 - val_accuracy: 0.9062 - val_precision: 0.9062 - val_recall: 0.9062 - val_auc: 0.9854 - val_f1_Score: 0.9015 - lr: 1.0000e-04 - 20s/epoch - 1s/step
# Epoch 23/30
# 15/15 - 15s - loss: 0.1692 - accuracy: 0.9333 - precision: 0.9333 - recall: 0.9333 - auc: 0.9799 - f1_Score: 0.9332 - val_loss: 0.1395 - val_accuracy: 0.9375 - val_precision: 0.9375 - val_recall: 0.9375 - val_auc: 0.9883 - val_f1_Score: 0.9375 - lr: 1.0000e-04 - 15s/epoch - 1s/step
# Epoch 24/30
# 15/15 - 17s - loss: 0.2236 - accuracy: 0.9208 - precision: 0.9208 - recall: 0.9208 - auc: 0.9712 - f1_Score: 0.9208 - val_loss: 0.0443 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000 - val_f1_Score: 1.0000 - lr: 1.0000e-04 - 17s/epoch - 1s/step
# Epoch 25/30
# 15/15 - 18s - loss: 0.1802 - accuracy: 0.9333 - precision: 0.9333 - recall: 0.9333 - auc: 0.9788 - f1_Score: 0.9333 - val_loss: 0.0283 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000 - val_f1_Score: 1.0000 - lr: 1.0000e-04 - 18s/epoch - 1s/step
# Epoch 26/30
# 15/15 - 16s - loss: 0.1673 - accuracy: 0.9375 - precision: 0.9375 - recall: 0.9375 - auc: 0.9826 - f1_Score: 0.9374 - val_loss: 0.0655 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000 - val_f1_Score: 1.0000 - lr: 1.0000e-04 - 16s/epoch - 1s/step
# Epoch 27/30
# 15/15 - 12s - loss: 0.1349 - accuracy: 0.9667 - precision: 0.9667 - recall: 0.9667 - auc: 0.9874 - f1_Score: 0.9666 - val_loss: 0.1576 - val_accuracy: 0.9062 - val_precision: 0.9062 - val_recall: 0.9062 - val_auc: 0.9883 - val_f1_Score: 0.9062 - lr: 1.0000e-04 - 12s/epoch - 827ms/step
# Epoch 28/30
# 15/15 - 15s - loss: 0.1037 - accuracy: 0.9667 - precision: 0.9667 - recall: 0.9667 - auc: 0.9949 - f1_Score: 0.9666 - val_loss: 0.1040 - val_accuracy: 0.9062 - val_precision: 0.9062 - val_recall: 0.9062 - val_auc: 0.9912 - val_f1_Score: 0.8937 - lr: 1.0000e-04 - 15s/epoch - 1s/step
# Epoch 29/30
# 15/15 - 16s - loss: 0.1312 - accuracy: 0.9500 - precision: 0.9500 - recall: 0.9500 - auc: 0.9899 - f1_Score: 0.9497 - val_loss: 0.1311 - val_accuracy: 0.9062 - val_precision: 0.9062 - val_recall: 0.9062 - val_auc: 0.9893 - val_f1_Score: 0.8982 - lr: 1.0000e-04 - 16s/epoch - 1s/step
# Epoch 30/30
# 15/15 - 16s - loss: 0.1732 - accuracy: 0.9417 - precision: 0.9417 - recall: 0.9417 - auc: 0.9819 - f1_Score: 0.9416 - val_loss: 0.0441 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000 - val_f1_Score: 1.0000 - lr: 1.0000e-04 - 16s/epoch - 1s/step

# %% [markdown]
# ## **5. Plotting the Model Metrics**
# ### i. Plotting training and validation accuracy, loss and learning rate

# %%
plt.figure( figsize = (15,8)) 
    
plt.subplot(221)  
# Accuracy 
plt.plot(model.history.history['accuracy'])
plt.plot(model.history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Training set', 'Validation set'], loc='upper left')
plt.show()


# Loss
plt.figure( figsize = (15,8)) 
plt.subplot(222)  
plt.plot(model.history.history['loss'])
plt.plot(model.history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Training set', 'Validation set'], loc='upper left')
plt.show()

# %%
train_accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

train_loss = history.history['loss']
val_loss = history.history['val_loss']

learning_rate = history.history['lr']
# ans = history.history['val_auc']
# ans

# %%
train_accuracy
# Out:
# [0.6625000238418579,
#  0.7875000238418579,
#  0.8208333253860474,
#  0.8355555534362793,
#  0.8708333373069763,
#  0.9208333492279053,
#  0.875,
#  0.8791666626930237,
#  0.9083333611488342,
#  0.9375,
#  0.8844444155693054,
#  0.8833333253860474,
#  0.8999999761581421,
#  0.9208333492279053,
#  0.9041666388511658,
#  0.9083333611488342,
#  0.9458333253860474,
#  0.925000011920929,
#  0.9333333373069763,
#  0.9208333492279053,
#  0.9583333134651184,
#  0.9333333373069763,
#  0.9333333373069763,
#  0.9208333492279053,
#  0.9333333373069763,
#  0.9375,
#  0.9666666388511658,
#  0.9666666388511658,
#  0.949999988079071,
#  0.9416666626930237]

# %%
fig, ax = plt.subplots(nrows=3, ncols=1, figsize=(12, 10))

ax[0].set_title('Training Accuracy vs. Epochs')
ax[0].plot(train_accuracy, 'o-', label='Train Accuracy')
ax[0].plot(val_accuracy, 'o-', label='Validation Accuracy')
ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Accuracy')
ax[0].legend(loc='best')

ax[1].set_title('Training/Validation Loss vs. Epochs')
ax[1].plot(train_loss, 'o-', label='Train Loss')
ax[1].plot(val_loss, 'o-', label='Validation Loss')
ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Loss')
ax[1].legend(loc='best')

ax[2].set_title('Learning Rate vs. Epochs')
ax[2].plot(learning_rate, 'o-', label='Learning Rate')
ax[2].set_xlabel('Epochs')
ax[2].set_ylabel('Loss')
ax[2].legend(loc='best')

plt.tight_layout()
plt.show()

# %%
def Train_Val_Plot(acc,val_acc,loss,val_loss,auc,val_auc,precision,val_precision,f1_Score,val_f1_Score):
    
    fig, (ax1, ax2,ax3,ax4,ax5) = plt.subplots(1,5, figsize= (20,5))
    fig.suptitle(" MODEL'S METRICS VISUALIZATION ")

    ax1.plot(range(1, len(acc) + 1), acc)
    ax1.plot(range(1, len(val_acc) + 1), val_acc)
    ax1.set_title('History of Accuracy')
    ax1.set_xlabel('Epochs')
    ax1.set_ylabel('Accuracy')
    ax1.legend(['training', 'validation'])


    ax2.plot(range(1, len(loss) + 1), loss)
    ax2.plot(range(1, len(val_loss) + 1), val_loss)
    ax2.set_title('History of Loss')
    ax2.set_xlabel('Epochs')
    ax2.set_ylabel('Loss')
    ax2.legend(['training', 'validation'])
    
    ax3.plot(range(1, len(auc) + 1), auc)
    ax3.plot(range(1, len(val_auc) + 1), val_auc)
    ax3.set_title('History of AUC')
    ax3.set_xlabel('Epochs')
    ax3.set_ylabel('AUC')
    ax3.legend(['training', 'validation'])
    
    ax4.plot(range(1, len(precision) + 1), precision)
    ax4.plot(range(1, len(val_precision) + 1), val_precision)
    ax4.set_title('History of Precision')
    ax4.set_xlabel('Epochs')
    ax4.set_ylabel('Precision')
    ax4.legend(['training', 'validation'])
    
    ax5.plot(range(1, len(f1_Score) + 1), f1_Score)
    ax5.plot(range(1, len(val_f1_Score) + 1), val_f1_Score)
    ax5.set_title('History of F1-score')
    ax5.set_xlabel('Epochs')
    ax5.set_ylabel('F1 score')
    ax5.legend(['training', 'validation'])


    plt.show()
    
import numpy as np
# f1_s= np.mean(history.history['f1_Score'])
# val_f1_s= np.mean(history.history['val_f1_Score'])
Train_Val_Plot(history.history['accuracy'],history.history['val_accuracy'],
               history.history['loss'],history.history['val_loss'],
               history.history['auc'],history.history['val_auc'],
               history.history['precision'],history.history['val_precision']
              #  f1_s,val_f1_s

                , history.history['f1_Score'],history.history['val_f1_Score']
              )

# %% [markdown]
# ## 6. Testing the Model on Test Set
# Testing the model on the validation dataset because a seperate dataset for testing is not available.

# %%
test_dataset = '/content/drive/MyDrive/FYP/test'

# %%
test_datagen = ImageDataGenerator(rescale=1.0/255)

test_generator = test_datagen.flow_from_directory(test_dataset,
                                                 shuffle=False,
                                                 batch_size=BATCH_SIZE,
                                                 target_size = (IMG_WIDTH, IMG_HEIGHT),
                                                 class_mode='categorical')
# Out:
# Found 3000 images belonging to 2 classes.

# %% [markdown]
# ## 7. Model Prediction on the Test Dataset

# %%
predictions = model.predict(test_generator)
# Out:
# 188/188 [==============================] - 386s 2s/step

# %%
fig, ax = plt.subplots(nrows=2, ncols=5, figsize=(12, 10))
idx = 0

for i in range(2):
    for j in range(5):
        predicted_label = labels[np.argmax(predictions[idx])]
        ax[i, j].set_title(f"{predicted_label}")
        ax[i, j].imshow(test_generator[0][0][idx])
        ax[i, j].axis("off")
        idx += 1

plt.tight_layout()
plt.suptitle("Test Dataset Predictions", fontsize=20)
plt.show()

# %%
train_loss, train_accuracy, train_precision, train_recall, train_auc, train_F1_Score = model.evaluate(train_generator, batch_size=BATCH_SIZE)
# Out:
# 189/189 [==============================] - 70s 366ms/step - loss: 0.0901 - accuracy: 0.9668 - precision: 0.9668 - recall: 0.9668 - auc: 0.9948 - f1_Score: 0.9668

# %%
print(f"Train Loss:     {train_loss}")
print(f"Train Accuracy: {train_accuracy}")
print(f"Train Precision: {train_precision}")
print(f"Train Recall: {train_recall}")
print(f"Train AUC: {train_auc}")
print(f"Train F1_Score: {np.mean(train_F1_Score)}")
# Out:
# Train Loss:     0.09008679538965225
# Train Accuracy: 0.966766357421875
# Train Precision: 0.966766357421875
# Train Recall: 0.966766357421875
# Train AUC: 0.9947545528411865
# Train F1_Score: 0.9667655229568481

# %%
test_loss, test_accuracy, test_precision, test_recall, test_auc, test_F1_Score = model.evaluate(test_generator, batch_size=BATCH_SIZE)
# Out:
# 188/188 [==============================] - 36s 189ms/step - loss: 0.1183 - accuracy: 0.9520 - precision: 0.9520 - recall: 0.9520 - auc: 0.9916 - f1_Score: 0.9519

# %%
print(f"Test Loss:     {test_loss}")
print(f"Test Accuracy: {test_accuracy}")
print(f"Test Precision: {test_precision}")
print(f"Test Recall: {test_recall}")
print(f"Test AUC: {test_auc}")
print(f"Test F1_Score: {np.mean(test_F1_Score)}")
# Out:
# Test Loss:     0.11825232207775116
# Test Accuracy: 0.9520000219345093
# Test Precision: 0.9520000219345093
# Test Recall: 0.9520000219345093
# Test AUC: 0.9916049838066101
# Test F1_Score: 0.9519151449203491

# %% [markdown]
# ## **8. Plotting the Classification Metrics**
# ### i. Confusion Matrix

# %%
y_pred = np.argmax(predictions, axis=1)
y_true = test_generator.classes

# %%
cf_mtx = confusion_matrix(y_true, y_pred)

group_counts = ["{0:0.0f}".format(value) for value in cf_mtx.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in cf_mtx.flatten()/np.sum(cf_mtx)]
box_labels = [f"{v1}\n({v2})" for v1, v2 in zip(group_counts, group_percentages)]
box_labels = np.asarray(box_labels).reshape(2, 2)

plt.figure(figsize = (12, 10))
sns.heatmap(cf_mtx, xticklabels=labels.values(), yticklabels=labels.values(),
           cmap="YlGnBu", fmt="", annot=box_labels)
plt.xlabel('Predicted Classes')
plt.ylabel('True Classes')
plt.show()

# %%
print(classification_report(y_true, y_pred, target_names=labels.values()))
# Out:
#               precision    recall  f1-score   support
#
#      Nonnude       0.99      0.91      0.95      1500
#         Nude       0.92      0.99      0.95      1500
#
#     accuracy                           0.95      3000
#    macro avg       0.96      0.95      0.95      3000
# weighted avg       0.96      0.95      0.95      3000

# %%
A=history.history['accuracy']
A_v=history.history['val_accuracy']
L=history.history['loss']
L_v=history.history['val_loss']
Auc=history.history['auc']
Auc_v=history.history['val_auc']
P=history.history['precision']
P_v=history.history['val_precision']
F1=history.history['f1_Score']
F1_v=history.history['val_f1_Score']

# %%
import pandas as pd
data_to_submit = pd.DataFrame({
    'accuracy':A,
    'val_accuracy':A_v,
    'loss': L,
    'val_loss': L_v,
    'auc':Auc,
    'val_auc':Auc_v,
    'precision':P,
    'val_precision':P_v,
    'f1_score':F1,
    'val_f1_score':F1_v
})
data_to_submit.to_csv('csv_to_submit.csv', index = False)
