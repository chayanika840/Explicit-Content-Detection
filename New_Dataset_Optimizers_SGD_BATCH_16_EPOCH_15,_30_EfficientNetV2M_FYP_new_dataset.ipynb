# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## **Importing necessary packages**

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import cv2
import os

import warnings
warnings.filterwarnings('ignore')

from sklearn.metrics import confusion_matrix, classification_report

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation, BatchNormalization, Conv2D, Dense, Dropout, Flatten, MaxPool2D,MaxPooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping

# %% [markdown]
# ## **2. Load the Image Training and Validation Datasets**
#
# ### i. Get the Image Dataset Paths

# %%
train_dataset_path = '/content/drive/MyDrive/FYP/train'
validation_dataset_path = '/content/drive/MyDrive/FYP/val'

# %% [markdown]
# ### ii. Load Image Datasets and Apply Augmentations
# Since the images present in the datasets are 150x150px in size, the image height and width are taken as 150, 150 respectively. The batch size value can be changed if required.

# %%
IMG_WIDTH = 150
IMG_HEIGHT = 150
BATCH_SIZE = 16

# %% [markdown]
# Loading the training dataset and applying augmentations on it.

# %%
train_datagen = ImageDataGenerator(rescale=1.0/255,
                                  zoom_range=0.2,
                                  width_shift_range=0.2,
                                  height_shift_range=0.2,
                                  fill_mode='nearest')
train_generator = train_datagen.flow_from_directory(train_dataset_path,
                                                   target_size=(IMG_WIDTH, IMG_HEIGHT),
                                                   batch_size=BATCH_SIZE,
                                                   class_mode='categorical',
                                                   shuffle=True)
# Out:
# Found 3009 images belonging to 2 classes.

# %% [markdown]
# Loading the validation dataset.

# %%
validation_datagen = ImageDataGenerator(rescale=1.0/255)
validation_generator = validation_datagen.flow_from_directory(validation_dataset_path,
                                                             target_size=(IMG_WIDTH, IMG_HEIGHT),
                                                             batch_size=BATCH_SIZE,
                                                             class_mode='categorical',
                                                             shuffle=True)
# Out:
# Found 3019 images belonging to 2 classes.

# %% [markdown]
# ### iii. Get the Label Mappings
# The labels dictionary is made in order to retrive the class names against the label indices used for training the model

# %%
labels = {value: key for key, value in train_generator.class_indices.items()}

print("Label Mappings for classes present in the training and validation datasets\n")
for key, value in labels.items():
    print(f"{key} : {value}")
# Out:
# Label Mappings for classes present in the training and validation datasets
#
# 0 : Nonnude
# 1 : Nude

# %% [markdown]
# ## **3. Plotting Sample Training Image**s

# %%
fig, ax = plt.subplots(nrows=2, ncols=5, figsize=(15, 12))
idx = 0

for i in range(2):
    for j in range(5):
        label = labels[np.argmax(train_generator[0][1][idx])]
        ax[i, j].set_title(f"{label}")
        ax[i, j].imshow(train_generator[0][0][idx][:, :, :])
        ax[i, j].axis("off")
        idx += 1

plt.tight_layout()
plt.suptitle("Sample Training Images", fontsize=21)
plt.show()

# %% [markdown]
# ## **4. Training a EfficientNetV2M Model**
#
#
# ### i. Create a EfficientNetV2M Model

# %%
base_model = tf.keras.applications.EfficientNetV2M(
                     include_top=False,
                     weights='imagenet',
                     input_shape=(150,150,3),
                     include_preprocessing=True
                     )

base_model.trainable=True
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/efficientnet_v2/efficientnetv2-m_notop.h5
# 214201816/214201816 [==============================] - 1s 0us/step

# %%
model = tf.keras.Sequential([
        base_model,  
        tf.keras.layers.BatchNormalization(renorm=True),
        tf.keras.layers.GlobalAveragePooling2D(),
        tf.keras.layers.Dense(512, activation='relu'),
        tf.keras.layers.Dense(256, activation='relu'),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.Dense(128, activation='relu'),
        tf.keras.layers.Dense(2, activation='softmax')
    ])

# %%
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  efficientnetv2-m (Functiona  (None, 5, 5, 1280)       53150388
#  l)
#
#  batch_normalization (BatchN  (None, 5, 5, 1280)       8960
#  ormalization)
#
#  global_average_pooling2d (G  (None, 1280)             0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 512)               655872
#
#  dense_1 (Dense)             (None, 256)               131328
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_2 (Dense)             (None, 128)               32896
#
#  dense_3 (Dense)             (None, 2)                 258
#
# =================================================================
# Total params: 53,979,702
# Trainable params: 53,681,270
# Non-trainable params: 298,432
# _________________________________________________________________
# None

# %% [markdown]
# ### ii. Defining Callbacks
# A callback is an object that can perform actions at various stages of training (e.g. at the start or end of an epoch, before or after a single batch, etc)
#
# a. Reduce Learning Rate on Plateau
# Is used to reduce the learning rate when a metric has stopped improving.

# %%
# !pip install tensorflow_addons
import tensorflow_addons as tfa
METRICS = [
      # tf.keras.metrics.BinaryAccuracy(name='binary_accuracy'),
      # tf.keras.metrics.Accuracy(name='accuracy'),
      tf.keras.metrics.CategoricalAccuracy(name='accuracy'),
      tf.keras.metrics.Precision(name='precision'),
      tf.keras.metrics.Recall(name='recall'),  
      tf.keras.metrics.AUC(name='auc'),
      # tf.keras.metrics.F1Score(name='F1'),
      tfa.metrics.F1Score(num_classes= 2,name="f1_Score")

    
]
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tensorflow_addons
#   Downloading tensorflow_addons-0.19.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 39.0 MB/s eta 0:00:00
# Collecting typeguard>=2.7
#   Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from tensorflow_addons) (23.0)
# Installing collected packages: typeguard, tensorflow_addons
# Successfully installed tensorflow_addons-0.19.0 typeguard-2.13.3

# %%
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=np.sqrt(0.1), patience=5)
# early = tf.keras.callbacks.EarlyStopping( patience=10,
#                                           min_delta=0.001,
#                                           restore_best_weights=True)

# %% [markdown]
# ### iii. Defining the Optimizer

# %%
optimizer = Adam(lr=0.001)
sgd = SGD(lr=0.001)
# Out:
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.SGD.

# %% [markdown]
# ### iv. Compile the Model

# %%
# cnn_model.compile(optimizer=optimizer, loss=CategoricalCrossentropy(), metrics=['accuracy'])
model.compile(optimizer=sgd,loss='categorical_crossentropy',metrics=METRICS)

# %% [markdown]
# ### v. Training the Model

# %%
history = model.fit(train_generator,
                    steps_per_epoch=15,
                    validation_data=validation_generator,
                    validation_steps=2,
                    epochs=30,verbose = 2,
                    callbacks=[reduce_lr])
# Out:
# Epoch 1/30
# WARNING:tensorflow:From /usr/local/lib/python3.9/dist-packages/tensorflow/python/autograph/pyct/static_analysis/liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089
# 15/15 - 258s - loss: 0.7021 - accuracy: 0.5167 - precision: 0.5167 - recall: 0.5167 - auc: 0.5223 - f1_Score: 0.4965 - val_loss: 0.7050 - val_accuracy: 0.3125 - val_precision: 0.3125 - val_recall: 0.3125 - val_auc: 0.3232 - val_f1_Score: 0.3016 - lr: 0.0100 - 258s/epoch - 17s/step
# Epoch 2/30
# 15/15 - 178s - loss: 0.7130 - accuracy: 0.4833 - precision: 0.4833 - recall: 0.4833 - auc: 0.4773 - f1_Score: 0.4820 - val_loss: 0.7030 - val_accuracy: 0.5938 - val_precision: 0.5938 - val_recall: 0.5938 - val_auc: 0.4097 - val_f1_Score: 0.5836 - lr: 0.0100 - 178s/epoch - 12s/step
# Epoch 3/30
# 15/15 - 168s - loss: 0.6806 - accuracy: 0.5708 - precision: 0.5708 - recall: 0.5708 - auc: 0.6118 - f1_Score: 0.5579 - val_loss: 0.7174 - val_accuracy: 0.3750 - val_precision: 0.3750 - val_recall: 0.3750 - val_auc: 0.2954 - val_f1_Score: 0.3333 - lr: 0.0100 - 168s/epoch - 11s/step
# Epoch 4/30
# 15/15 - 175s - loss: 0.6820 - accuracy: 0.5542 - precision: 0.5542 - recall: 0.5542 - auc: 0.5862 - f1_Score: 0.5524 - val_loss: 0.7200 - val_accuracy: 0.3438 - val_precision: 0.3438 - val_recall: 0.3438 - val_auc: 0.3081 - val_f1_Score: 0.3379 - lr: 0.0100 - 175s/epoch - 12s/step
# Epoch 5/30
# 15/15 - 194s - loss: 0.6478 - accuracy: 0.6667 - precision: 0.6667 - recall: 0.6667 - auc: 0.7001 - f1_Score: 0.6666 - val_loss: 0.6915 - val_accuracy: 0.5312 - val_precision: 0.5312 - val_recall: 0.5312 - val_auc: 0.5093 - val_f1_Score: 0.5308 - lr: 0.0100 - 194s/epoch - 13s/step
# Epoch 6/30
# 15/15 - 165s - loss: 0.6333 - accuracy: 0.6458 - precision: 0.6458 - recall: 0.6458 - auc: 0.7142 - f1_Score: 0.6426 - val_loss: 0.6820 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5474 - val_f1_Score: 0.4921 - lr: 0.0100 - 165s/epoch - 11s/step
# Epoch 7/30
# 15/15 - 163s - loss: 0.6114 - accuracy: 0.6875 - precision: 0.6875 - recall: 0.6875 - auc: 0.7495 - f1_Score: 0.6859 - val_loss: 0.7106 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.4688 - val_f1_Score: 0.3816 - lr: 0.0100 - 163s/epoch - 11s/step
# Epoch 8/30
# 15/15 - 153s - loss: 0.5990 - accuracy: 0.6756 - precision: 0.6756 - recall: 0.6756 - auc: 0.7580 - f1_Score: 0.6743 - val_loss: 0.7044 - val_accuracy: 0.4688 - val_precision: 0.4688 - val_recall: 0.4688 - val_auc: 0.4727 - val_f1_Score: 0.3637 - lr: 0.0100 - 153s/epoch - 10s/step
# Epoch 9/30
# 15/15 - 165s - loss: 0.5287 - accuracy: 0.7792 - precision: 0.7792 - recall: 0.7792 - auc: 0.8476 - f1_Score: 0.7783 - val_loss: 0.7655 - val_accuracy: 0.4375 - val_precision: 0.4375 - val_recall: 0.4375 - val_auc: 0.4297 - val_f1_Score: 0.4000 - lr: 0.0100 - 165s/epoch - 11s/step
# Epoch 10/30
# 15/15 - 169s - loss: 0.5178 - accuracy: 0.7733 - precision: 0.7733 - recall: 0.7733 - auc: 0.8355 - f1_Score: 0.7729 - val_loss: 0.7225 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.6426 - val_f1_Score: 0.4182 - lr: 0.0100 - 169s/epoch - 11s/step
# Epoch 11/30
# 15/15 - 166s - loss: 0.5029 - accuracy: 0.7667 - precision: 0.7667 - recall: 0.7667 - auc: 0.8388 - f1_Score: 0.7607 - val_loss: 0.6389 - val_accuracy: 0.5938 - val_precision: 0.5938 - val_recall: 0.5938 - val_auc: 0.7061 - val_f1_Score: 0.3725 - lr: 0.0100 - 166s/epoch - 11s/step
# Epoch 12/30
# 15/15 - 173s - loss: 0.4598 - accuracy: 0.7833 - precision: 0.7833 - recall: 0.7833 - auc: 0.8737 - f1_Score: 0.7789 - val_loss: 0.6570 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.6367 - val_f1_Score: 0.4921 - lr: 0.0100 - 173s/epoch - 12s/step
# Epoch 13/30
# 15/15 - 172s - loss: 0.5015 - accuracy: 0.7667 - precision: 0.7667 - recall: 0.7667 - auc: 0.8337 - f1_Score: 0.7650 - val_loss: 0.7586 - val_accuracy: 0.4375 - val_precision: 0.4375 - val_recall: 0.4375 - val_auc: 0.4580 - val_f1_Score: 0.4170 - lr: 0.0100 - 172s/epoch - 11s/step
# Epoch 14/30
# 15/15 - 181s - loss: 0.4246 - accuracy: 0.8250 - precision: 0.8250 - recall: 0.8250 - auc: 0.8964 - f1_Score: 0.8249 - val_loss: 1.0043 - val_accuracy: 0.4062 - val_precision: 0.4062 - val_recall: 0.4062 - val_auc: 0.5576 - val_f1_Score: 0.2889 - lr: 0.0100 - 181s/epoch - 12s/step
# Epoch 15/30
# 15/15 - 162s - loss: 0.4032 - accuracy: 0.7875 - precision: 0.7875 - recall: 0.7875 - auc: 0.8977 - f1_Score: 0.7875 - val_loss: 0.5098 - val_accuracy: 0.7812 - val_precision: 0.7812 - val_recall: 0.7812 - val_auc: 0.8438 - val_f1_Score: 0.7703 - lr: 0.0100 - 162s/epoch - 11s/step
# Epoch 16/30
# 15/15 - 169s - loss: 0.4534 - accuracy: 0.8167 - precision: 0.8167 - recall: 0.8167 - auc: 0.8744 - f1_Score: 0.8162 - val_loss: 0.9597 - val_accuracy: 0.4688 - val_precision: 0.4688 - val_recall: 0.4688 - val_auc: 0.4385 - val_f1_Score: 0.4421 - lr: 0.0100 - 169s/epoch - 11s/step
# Epoch 17/30
# 15/15 - 166s - loss: 0.3966 - accuracy: 0.8250 - precision: 0.8250 - recall: 0.8250 - auc: 0.9035 - f1_Score: 0.8250 - val_loss: 0.9736 - val_accuracy: 0.4062 - val_precision: 0.4062 - val_recall: 0.4062 - val_auc: 0.5352 - val_f1_Score: 0.2889 - lr: 0.0100 - 166s/epoch - 11s/step
# Epoch 18/30
# 15/15 - 160s - loss: 0.3969 - accuracy: 0.7956 - precision: 0.7956 - recall: 0.7956 - auc: 0.9008 - f1_Score: 0.7956 - val_loss: 0.5515 - val_accuracy: 0.7188 - val_precision: 0.7188 - val_recall: 0.7188 - val_auc: 0.7861 - val_f1_Score: 0.6946 - lr: 0.0100 - 160s/epoch - 11s/step
# Epoch 19/30
# 15/15 - 176s - loss: 0.3650 - accuracy: 0.8542 - precision: 0.8542 - recall: 0.8542 - auc: 0.9234 - f1_Score: 0.8540 - val_loss: 0.6445 - val_accuracy: 0.5938 - val_precision: 0.5938 - val_recall: 0.5938 - val_auc: 0.6416 - val_f1_Score: 0.5934 - lr: 0.0100 - 176s/epoch - 12s/step
# Epoch 20/30
# 15/15 - 173s - loss: 0.3801 - accuracy: 0.8375 - precision: 0.8375 - recall: 0.8375 - auc: 0.9102 - f1_Score: 0.8374 - val_loss: 0.4906 - val_accuracy: 0.7500 - val_precision: 0.7500 - val_recall: 0.7500 - val_auc: 0.8467 - val_f1_Score: 0.7333 - lr: 0.0100 - 173s/epoch - 12s/step
# Epoch 21/30
# 15/15 - 172s - loss: 0.3770 - accuracy: 0.8000 - precision: 0.8000 - recall: 0.8000 - auc: 0.9088 - f1_Score: 0.8000 - val_loss: 0.6573 - val_accuracy: 0.6250 - val_precision: 0.6250 - val_recall: 0.6250 - val_auc: 0.6660 - val_f1_Score: 0.6250 - lr: 0.0100 - 172s/epoch - 11s/step
# Epoch 22/30
# 15/15 - 169s - loss: 0.3375 - accuracy: 0.8500 - precision: 0.8500 - recall: 0.8500 - auc: 0.9300 - f1_Score: 0.8499 - val_loss: 0.6353 - val_accuracy: 0.6562 - val_precision: 0.6562 - val_recall: 0.6562 - val_auc: 0.7607 - val_f1_Score: 0.6267 - lr: 0.0100 - 169s/epoch - 11s/step
# Epoch 23/30
# 15/15 - 167s - loss: 0.3248 - accuracy: 0.8500 - precision: 0.8500 - recall: 0.8500 - auc: 0.9362 - f1_Score: 0.8500 - val_loss: 0.6712 - val_accuracy: 0.5938 - val_precision: 0.5938 - val_recall: 0.5938 - val_auc: 0.6475 - val_f1_Score: 0.5901 - lr: 0.0100 - 167s/epoch - 11s/step
# Epoch 24/30
# 15/15 - 165s - loss: 0.3998 - accuracy: 0.8208 - precision: 0.8208 - recall: 0.8208 - auc: 0.9050 - f1_Score: 0.8189 - val_loss: 0.9101 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5850 - val_f1_Score: 0.3816 - lr: 0.0100 - 165s/epoch - 11s/step
# Epoch 25/30
# 15/15 - 169s - loss: 0.4108 - accuracy: 0.7958 - precision: 0.7958 - recall: 0.7958 - auc: 0.8931 - f1_Score: 0.7957 - val_loss: 0.7190 - val_accuracy: 0.5938 - val_precision: 0.5938 - val_recall: 0.5938 - val_auc: 0.5762 - val_f1_Score: 0.5589 - lr: 0.0100 - 169s/epoch - 11s/step
# Epoch 26/30
# 15/15 - 169s - loss: 0.3224 - accuracy: 0.8583 - precision: 0.8583 - recall: 0.8583 - auc: 0.9362 - f1_Score: 0.8569 - val_loss: 0.8289 - val_accuracy: 0.5938 - val_precision: 0.5938 - val_recall: 0.5938 - val_auc: 0.7163 - val_f1_Score: 0.5393 - lr: 0.0032 - 169s/epoch - 11s/step
# Epoch 27/30
# 15/15 - 168s - loss: 0.2931 - accuracy: 0.8792 - precision: 0.8792 - recall: 0.8792 - auc: 0.9489 - f1_Score: 0.8791 - val_loss: 0.5855 - val_accuracy: 0.6875 - val_precision: 0.6875 - val_recall: 0.6875 - val_auc: 0.7422 - val_f1_Score: 0.6875 - lr: 0.0032 - 168s/epoch - 11s/step
# Epoch 28/30
# 15/15 - 175s - loss: 0.3216 - accuracy: 0.8583 - precision: 0.8583 - recall: 0.8583 - auc: 0.9359 - f1_Score: 0.8580 - val_loss: 1.0237 - val_accuracy: 0.3750 - val_precision: 0.3750 - val_recall: 0.3750 - val_auc: 0.3945 - val_f1_Score: 0.3522 - lr: 0.0032 - 175s/epoch - 12s/step
# Epoch 29/30
# 15/15 - 168s - loss: 0.3239 - accuracy: 0.8458 - precision: 0.8458 - recall: 0.8458 - auc: 0.9337 - f1_Score: 0.8455 - val_loss: 0.7534 - val_accuracy: 0.4688 - val_precision: 0.4688 - val_recall: 0.4688 - val_auc: 0.5884 - val_f1_Score: 0.3637 - lr: 0.0032 - 168s/epoch - 11s/step
# Epoch 30/30
# 15/15 - 171s - loss: 0.3546 - accuracy: 0.8542 - precision: 0.8542 - recall: 0.8542 - auc: 0.9213 - f1_Score: 0.8526 - val_loss: 1.5710 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5967 - val_f1_Score: 0.3333 - lr: 0.0032 - 171s/epoch - 11s/step

# %% [markdown]
# ## **5. Plotting the Model Metrics**
# ### i. Plotting training and validation accuracy, loss and learning rate

# %%
plt.figure( figsize = (15,8)) 
    
plt.subplot(221)  
# Accuracy 
plt.plot(model.history.history['accuracy'])
plt.plot(model.history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Training set', 'Validation set'], loc='upper left')
plt.show()


# Loss
plt.figure( figsize = (15,8)) 
plt.subplot(222)  
plt.plot(model.history.history['loss'])
plt.plot(model.history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Training set', 'Validation set'], loc='upper left')
plt.show()

# %%
train_accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

train_loss = history.history['loss']
val_loss = history.history['val_loss']

learning_rate = history.history['lr']
# ans = history.history['val_auc']
# ans

# %%
train_accuracy
# Out:
# [0.5166666507720947,
#  0.4833333194255829,
#  0.5708333253860474,
#  0.5541666746139526,
#  0.6666666865348816,
#  0.6458333134651184,
#  0.6875,
#  0.6755555272102356,
#  0.7791666388511658,
#  0.7733333110809326,
#  0.7666666507720947,
#  0.7833333611488342,
#  0.7666666507720947,
#  0.824999988079071,
#  0.7875000238418579,
#  0.8166666626930237,
#  0.824999988079071,
#  0.7955555319786072,
#  0.8541666865348816,
#  0.8374999761581421,
#  0.800000011920929,
#  0.8500000238418579,
#  0.8500000238418579,
#  0.8208333253860474,
#  0.7958333492279053,
#  0.8583333492279053,
#  0.8791666626930237,
#  0.8583333492279053,
#  0.8458333611488342,
#  0.8541666865348816]

# %%
fig, ax = plt.subplots(nrows=3, ncols=1, figsize=(12, 10))

ax[0].set_title('Training Accuracy vs. Epochs')
ax[0].plot(train_accuracy, 'o-', label='Train Accuracy')
ax[0].plot(val_accuracy, 'o-', label='Validation Accuracy')
ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Accuracy')
ax[0].legend(loc='best')

ax[1].set_title('Training/Validation Loss vs. Epochs')
ax[1].plot(train_loss, 'o-', label='Train Loss')
ax[1].plot(val_loss, 'o-', label='Validation Loss')
ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Loss')
ax[1].legend(loc='best')

ax[2].set_title('Learning Rate vs. Epochs')
ax[2].plot(learning_rate, 'o-', label='Learning Rate')
ax[2].set_xlabel('Epochs')
ax[2].set_ylabel('Loss')
ax[2].legend(loc='best')

plt.tight_layout()
plt.show()

# %%
def Train_Val_Plot(acc,val_acc,loss,val_loss,auc,val_auc,precision,val_precision,f1_Score,val_f1_Score):
    
    fig, (ax1, ax2,ax3,ax4,ax5) = plt.subplots(1,5, figsize= (20,5))
    fig.suptitle(" MODEL'S METRICS VISUALIZATION ")

    ax1.plot(range(1, len(acc) + 1), acc)
    ax1.plot(range(1, len(val_acc) + 1), val_acc)
    ax1.set_title('History of Accuracy')
    ax1.set_xlabel('Epochs')
    ax1.set_ylabel('Accuracy')
    ax1.legend(['training', 'validation'])


    ax2.plot(range(1, len(loss) + 1), loss)
    ax2.plot(range(1, len(val_loss) + 1), val_loss)
    ax2.set_title('History of Loss')
    ax2.set_xlabel('Epochs')
    ax2.set_ylabel('Loss')
    ax2.legend(['training', 'validation'])
    
    ax3.plot(range(1, len(auc) + 1), auc)
    ax3.plot(range(1, len(val_auc) + 1), val_auc)
    ax3.set_title('History of AUC')
    ax3.set_xlabel('Epochs')
    ax3.set_ylabel('AUC')
    ax3.legend(['training', 'validation'])
    
    ax4.plot(range(1, len(precision) + 1), precision)
    ax4.plot(range(1, len(val_precision) + 1), val_precision)
    ax4.set_title('History of Precision')
    ax4.set_xlabel('Epochs')
    ax4.set_ylabel('Precision')
    ax4.legend(['training', 'validation'])
    
    ax5.plot(range(1, len(f1_Score) + 1), f1_Score)
    ax5.plot(range(1, len(val_f1_Score) + 1), val_f1_Score)
    ax5.set_title('History of F1-score')
    ax5.set_xlabel('Epochs')
    ax5.set_ylabel('F1 score')
    ax5.legend(['training', 'validation'])


    plt.show()
    
import numpy as np
# f1_s= np.mean(history.history['f1_Score'])
# val_f1_s= np.mean(history.history['val_f1_Score'])
Train_Val_Plot(history.history['accuracy'],history.history['val_accuracy'],
               history.history['loss'],history.history['val_loss'],
               history.history['auc'],history.history['val_auc'],
               history.history['precision'],history.history['val_precision']
              #  f1_s,val_f1_s

                , history.history['f1_Score'],history.history['val_f1_Score']
              )

# %% [markdown]
# ## 6. Testing the Model on Test Set
# Testing the model on the validation dataset because a seperate dataset for testing is not available.

# %%
test_dataset = '/content/drive/MyDrive/FYP/test'

# %%
test_datagen = ImageDataGenerator(rescale=1.0/255)

test_generator = test_datagen.flow_from_directory(test_dataset,
                                                 shuffle=False,
                                                 batch_size=BATCH_SIZE,
                                                 target_size = (IMG_WIDTH, IMG_HEIGHT),
                                                 class_mode='categorical')
# Out:
# Found 3000 images belonging to 2 classes.

# %% [markdown]
# ## 7. Model Prediction on the Test Dataset

# %%
predictions = model.predict(test_generator)
# Out:
# 188/188 [==============================] - 581s 3s/step

# %%
fig, ax = plt.subplots(nrows=2, ncols=5, figsize=(12, 10))
idx = 0

for i in range(2):
    for j in range(5):
        predicted_label = labels[np.argmax(predictions[idx])]
        ax[i, j].set_title(f"{predicted_label}")
        ax[i, j].imshow(test_generator[0][0][idx])
        ax[i, j].axis("off")
        idx += 1

plt.tight_layout()
plt.suptitle("Test Dataset Predictions", fontsize=20)
plt.show()

# %%
train_loss, train_accuracy, train_precision, train_recall, train_auc, train_F1_Score = model.evaluate(train_generator, batch_size=BATCH_SIZE)
# Out:
# 189/189 [==============================] - 456s 2s/step - loss: 1.6351 - accuracy: 0.5032 - precision: 0.5032 - recall: 0.5032 - auc: 0.5918 - f1_Score: 0.3383

# %%
print(f"Train Loss:     {train_loss}")
print(f"Train Accuracy: {train_accuracy}")
print(f"Train Precision: {train_precision}")
print(f"Train Recall: {train_recall}")
print(f"Train AUC: {train_auc}")
print(f"Train F1_Score: {np.mean(train_F1_Score)}")
# Out:
# Train Loss:     1.6351187229156494
# Train Accuracy: 0.5031571984291077
# Train Precision: 0.5031571984291077
# Train Recall: 0.5031571984291077
# Train AUC: 0.5918045043945312
# Train F1_Score: 0.33827534317970276

# %%
test_loss, test_accuracy, test_precision, test_recall, test_auc, test_F1_Score = model.evaluate(test_generator, batch_size=BATCH_SIZE)
# Out:
# 188/188 [==============================] - 443s 2s/step - loss: 1.4138 - accuracy: 0.5107 - precision: 0.5107 - recall: 0.5107 - auc: 0.6261 - f1_Score: 0.3577

# %%
print(f"Test Loss:     {test_loss}")
print(f"Test Accuracy: {test_accuracy}")
print(f"Test Precision: {test_precision}")
print(f"Test Recall: {test_recall}")
print(f"Test AUC: {test_auc}")
print(f"Test F1_Score: {np.mean(test_F1_Score)}")
# Out:
# Test Loss:     1.4138072729110718
# Test Accuracy: 0.5106666684150696
# Test Precision: 0.5106666684150696
# Test Recall: 0.5106666684150696
# Test AUC: 0.6260801553726196
# Test F1_Score: 0.3577088415622711

# %% [markdown]
# ## **8. Plotting the Classification Metrics**
# ### i. Confusion Matrix

# %%
y_pred = np.argmax(predictions, axis=1)
y_true = test_generator.classes

# %%
cf_mtx = confusion_matrix(y_true, y_pred)

group_counts = ["{0:0.0f}".format(value) for value in cf_mtx.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in cf_mtx.flatten()/np.sum(cf_mtx)]
box_labels = [f"{v1}\n({v2})" for v1, v2 in zip(group_counts, group_percentages)]
box_labels = np.asarray(box_labels).reshape(2, 2)

plt.figure(figsize = (12, 10))
sns.heatmap(cf_mtx, xticklabels=labels.values(), yticklabels=labels.values(),
           cmap="YlGnBu", fmt="", annot=box_labels)
plt.xlabel('Predicted Classes')
plt.ylabel('True Classes')
plt.show()

# %%
print(classification_report(y_true, y_pred, target_names=labels.values()))
# Out:
#               precision    recall  f1-score   support
#
#      Nonnude       0.51      1.00      0.67      1500
#         Nude       0.94      0.02      0.04      1500
#
#     accuracy                           0.51      3000
#    macro avg       0.72      0.51      0.36      3000
# weighted avg       0.72      0.51      0.36      3000

# %%
A=history.history['accuracy']
A_v=history.history['val_accuracy']
L=history.history['loss']
L_v=history.history['val_loss']
Auc=history.history['auc']
Auc_v=history.history['val_auc']
P=history.history['precision']
P_v=history.history['val_precision']
F1=history.history['f1_Score']
F1_v=history.history['val_f1_Score']

# %%
import pandas as pd
data_to_submit = pd.DataFrame({
    'accuracy':A,
    'val_accuracy':A_v,
    'loss': L,
    'val_loss': L_v,
    'auc':Auc,
    'val_auc':Auc_v,
    'precision':P,
    'val_precision':P_v,
    'f1_score':F1,
    'val_f1_score':F1_v
})
data_to_submit.to_csv('csv_to_submit.csv', index = False)
