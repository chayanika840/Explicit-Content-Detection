# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## **Importing necessary packages**

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import cv2
import os

import warnings
warnings.filterwarnings('ignore')

from sklearn.metrics import confusion_matrix, classification_report

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation, BatchNormalization, Conv2D, Dense, Dropout, Flatten, MaxPool2D,MaxPooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping

# %% [markdown]
# ## **2. Load the Image Training and Validation Datasets**
#
# ### i. Get the Image Dataset Paths

# %%
train_dataset_path = '/content/drive/MyDrive/FYP/train'
validation_dataset_path = '/content/drive/MyDrive/FYP/val'

# %% [markdown]
# ### ii. Load Image Datasets and Apply Augmentations
# Since the images present in the datasets are 150x150px in size, the image height and width are taken as 150, 150 respectively. The batch size value can be changed if required.

# %%
IMG_WIDTH = 150
IMG_HEIGHT = 150
BATCH_SIZE = 16

# %% [markdown]
# Loading the training dataset and applying augmentations on it.

# %%
train_datagen = ImageDataGenerator(rescale=1.0/255,
                                  zoom_range=0.2,
                                  width_shift_range=0.2,
                                  height_shift_range=0.2,
                                  fill_mode='nearest')
train_generator = train_datagen.flow_from_directory(train_dataset_path,
                                                   target_size=(IMG_WIDTH, IMG_HEIGHT),
                                                   batch_size=BATCH_SIZE,
                                                   class_mode='categorical',
                                                   shuffle=True)
# Out:
# Found 3009 images belonging to 2 classes.

# %% [markdown]
# Loading the validation dataset.

# %%
validation_datagen = ImageDataGenerator(rescale=1.0/255)
validation_generator = validation_datagen.flow_from_directory(validation_dataset_path,
                                                             target_size=(IMG_WIDTH, IMG_HEIGHT),
                                                             batch_size=BATCH_SIZE,
                                                             class_mode='categorical',
                                                             shuffle=True)
# Out:
# Found 3019 images belonging to 2 classes.

# %% [markdown]
# ### iii. Get the Label Mappings
# The labels dictionary is made in order to retrive the class names against the label indices used for training the model

# %%
labels = {value: key for key, value in train_generator.class_indices.items()}

print("Label Mappings for classes present in the training and validation datasets\n")
for key, value in labels.items():
    print(f"{key} : {value}")
# Out:
# Label Mappings for classes present in the training and validation datasets
#
# 0 : Nonnude
# 1 : Nude

# %% [markdown]
# ## **3. Plotting Sample Training Image**s

# %%
fig, ax = plt.subplots(nrows=2, ncols=5, figsize=(15, 12))
idx = 0

for i in range(2):
    for j in range(5):
        label = labels[np.argmax(train_generator[0][1][idx])]
        ax[i, j].set_title(f"{label}")
        ax[i, j].imshow(train_generator[0][0][idx][:, :, :])
        ax[i, j].axis("off")
        idx += 1

plt.tight_layout()
plt.suptitle("Sample Training Images", fontsize=21)
plt.show()

# %% [markdown]
# ## **4. Training a EfficientNetV2M Model**
#
#
# ### i. Create a EfficientNetV2M Model

# %%
base_model = tf.keras.applications.EfficientNetV2M(
                     include_top=False,
                     weights='imagenet',
                     input_shape=(150,150,3),
                     include_preprocessing=True
                     )

base_model.trainable=True

from sklearn.ensemble import VotingClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
import tensorflow as tf

# Define the models to use in the ensemble
model1 = tf.keras.models.Sequential()
# ... define architecture and compile for model1

model2 = tf.keras.models.Sequential()
# ... define architecture and compile for model2

model3 = tf.keras.models.Sequential()
# ... define architecture and compile for model3

# Create an ensemble model that uses majority voting
ensemble = VotingClassifier(estimators=[('model1', model1), ('model2', model2), ('model3', model3)], voting='soft')

# Train the ensemble model on the data
#x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)
#ensemble.fit(X_train, y_train)

# Evaluate the ensemble model on the test data
#y_pred = ensemble.predict(X_test)
#accuracy = accuracy_score(y_test, y_pred)
#print('Accuracy:', accuracy)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/efficientnet_v2/efficientnetv2-m_notop.h5
# 214201816/214201816 [==============================] - 7s 0us/step

# %%
model = tf.keras.Sequential([
        base_model,  
        tf.keras.layers.BatchNormalization(renorm=True),
        tf.keras.layers.GlobalAveragePooling2D(),
        tf.keras.layers.Dense(512, activation='relu'),
        tf.keras.layers.Dense(256, activation='relu'),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.Dense(128, activation='relu'),
        tf.keras.layers.Dense(2, activation='softmax')
    ])

# %%
print(model.summary())
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  efficientnetv2-m (Functiona  (None, 5, 5, 1280)       53150388
#  l)
#
#  batch_normalization (BatchN  (None, 5, 5, 1280)       8960
#  ormalization)
#
#  global_average_pooling2d (G  (None, 1280)             0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 512)               655872
#
#  dense_1 (Dense)             (None, 256)               131328
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_2 (Dense)             (None, 128)               32896
#
#  dense_3 (Dense)             (None, 2)                 258
#
# =================================================================
# Total params: 53,979,702
# Trainable params: 53,681,270
# Non-trainable params: 298,432
# _________________________________________________________________
# None

# %% [markdown]
# ### ii. Defining Callbacks
# A callback is an object that can perform actions at various stages of training (e.g. at the start or end of an epoch, before or after a single batch, etc)
#
# a. Reduce Learning Rate on Plateau
# Is used to reduce the learning rate when a metric has stopped improving.

# %%
# !pip install tensorflow_addons
import tensorflow_addons as tfa
METRICS = [
      # tf.keras.metrics.BinaryAccuracy(name='binary_accuracy'),
      # tf.keras.metrics.Accuracy(name='accuracy'),
      tf.keras.metrics.CategoricalAccuracy(name='accuracy'),
      tf.keras.metrics.Precision(name='precision'),
      tf.keras.metrics.Recall(name='recall'),  
      tf.keras.metrics.AUC(name='auc'),
      # tf.keras.metrics.F1Score(name='F1'),
      tfa.metrics.F1Score(num_classes= 2,name="f1_Score")

    
]
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tensorflow_addons
#   Downloading tensorflow_addons-0.19.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 34.0 MB/s eta 0:00:00
# Requirement already satisfied: typeguard>=2.7 in /usr/local/lib/python3.8/dist-packages (from tensorflow_addons) (2.7.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from tensorflow_addons) (23.0)
# Installing collected packages: tensorflow_addons
# Successfully installed tensorflow_addons-0.19.0

# %%
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=np.sqrt(0.1), patience=5)
# early = tf.keras.callbacks.EarlyStopping( patience=10,
#                                           min_delta=0.001,
#                                           restore_best_weights=True)

# %% [markdown]
# ### iii. Defining the Optimizer

# %%
optimizer = Adam(learning_rate=0.001)

# %% [markdown]
# ### iv. Compile the Model

# %%
# cnn_model.compile(optimizer=optimizer, loss=CategoricalCrossentropy(), metrics=['accuracy'])
model.compile(optimizer=optimizer,loss='categorical_crossentropy',metrics=METRICS)

# %% [markdown]
# ### v. Training the Model

# %%
history = model.fit(train_generator,
                    steps_per_epoch=15,
                    validation_data=validation_generator,
                    validation_steps=2,
                    epochs=30,verbose = 2,
                    callbacks=[reduce_lr])
# Out:
# Epoch 1/30
# 15/15 - 166s - loss: 0.6332 - accuracy: 0.6583 - precision: 0.6583 - recall: 0.6583 - auc: 0.7332 - f1_Score: 0.6577 - val_loss: 0.7349 - val_accuracy: 0.5312 - val_precision: 0.5312 - val_recall: 0.5312 - val_auc: 0.6035 - val_f1_Score: 0.3469 - lr: 0.0010 - 166s/epoch - 11s/step
# Epoch 2/30
# 15/15 - 84s - loss: 0.6455 - accuracy: 0.6417 - precision: 0.6417 - recall: 0.6417 - auc: 0.7102 - f1_Score: 0.6380 - val_loss: 20.4686 - val_accuracy: 0.5312 - val_precision: 0.5312 - val_recall: 0.5312 - val_auc: 0.5312 - val_f1_Score: 0.3469 - lr: 0.0010 - 84s/epoch - 6s/step
# Epoch 3/30
# 15/15 - 79s - loss: 0.5020 - accuracy: 0.7500 - precision: 0.7500 - recall: 0.7500 - auc: 0.8375 - f1_Score: 0.7491 - val_loss: 14.9725 - val_accuracy: 0.4062 - val_precision: 0.4062 - val_recall: 0.4062 - val_auc: 0.4062 - val_f1_Score: 0.2889 - lr: 0.0010 - 79s/epoch - 5s/step
# Epoch 4/30
# 15/15 - 74s - loss: 0.3960 - accuracy: 0.8583 - precision: 0.8583 - recall: 0.8583 - auc: 0.9274 - f1_Score: 0.8581 - val_loss: 0.2314 - val_accuracy: 0.8438 - val_precision: 0.8438 - val_recall: 0.8438 - val_auc: 0.9707 - val_f1_Score: 0.8424 - lr: 0.0010 - 74s/epoch - 5s/step
# Epoch 5/30
# 15/15 - 74s - loss: 0.5445 - accuracy: 0.7917 - precision: 0.7917 - recall: 0.7917 - auc: 0.8679 - f1_Score: 0.7916 - val_loss: 0.5143 - val_accuracy: 0.6562 - val_precision: 0.6562 - val_recall: 0.6562 - val_auc: 0.8096 - val_f1_Score: 0.6532 - lr: 0.0010 - 74s/epoch - 5s/step
# Epoch 6/30
# 15/15 - 68s - loss: 0.4525 - accuracy: 0.7778 - precision: 0.7778 - recall: 0.7778 - auc: 0.8749 - f1_Score: 0.7777 - val_loss: 0.8806 - val_accuracy: 0.6875 - val_precision: 0.6875 - val_recall: 0.6875 - val_auc: 0.7402 - val_f1_Score: 0.6761 - lr: 0.0010 - 68s/epoch - 5s/step
# Epoch 7/30
# 15/15 - 64s - loss: 0.6471 - accuracy: 0.7417 - precision: 0.7417 - recall: 0.7417 - auc: 0.8039 - f1_Score: 0.7414 - val_loss: 1.2532 - val_accuracy: 0.4688 - val_precision: 0.4688 - val_recall: 0.4688 - val_auc: 0.3828 - val_f1_Score: 0.3191 - lr: 0.0010 - 64s/epoch - 4s/step
# Epoch 8/30
# 15/15 - 57s - loss: 0.4809 - accuracy: 0.7750 - precision: 0.7750 - recall: 0.7750 - auc: 0.8572 - f1_Score: 0.7749 - val_loss: 1.7220 - val_accuracy: 0.5625 - val_precision: 0.5625 - val_recall: 0.5625 - val_auc: 0.7529 - val_f1_Score: 0.3600 - lr: 0.0010 - 57s/epoch - 4s/step
# Epoch 9/30
# 15/15 - 55s - loss: 0.5127 - accuracy: 0.8000 - precision: 0.8000 - recall: 0.8000 - auc: 0.8627 - f1_Score: 0.7983 - val_loss: 0.6472 - val_accuracy: 0.6250 - val_precision: 0.6250 - val_recall: 0.6250 - val_auc: 0.6733 - val_f1_Score: 0.6113 - lr: 0.0010 - 55s/epoch - 4s/step
# Epoch 10/30
# 15/15 - 46s - loss: 0.4113 - accuracy: 0.8500 - precision: 0.8500 - recall: 0.8500 - auc: 0.9022 - f1_Score: 0.8496 - val_loss: 0.8587 - val_accuracy: 0.6562 - val_precision: 0.6562 - val_recall: 0.6562 - val_auc: 0.7383 - val_f1_Score: 0.3962 - lr: 3.1623e-04 - 46s/epoch - 3s/step
# Epoch 11/30
# 15/15 - 48s - loss: 0.3673 - accuracy: 0.8750 - precision: 0.8750 - recall: 0.8750 - auc: 0.9207 - f1_Score: 0.8750 - val_loss: 0.3456 - val_accuracy: 0.8750 - val_precision: 0.8750 - val_recall: 0.8750 - val_auc: 0.9277 - val_f1_Score: 0.8704 - lr: 3.1623e-04 - 48s/epoch - 3s/step
# Epoch 12/30
# 15/15 - 43s - loss: 0.3176 - accuracy: 0.8708 - precision: 0.8708 - recall: 0.8708 - auc: 0.9373 - f1_Score: 0.8708 - val_loss: 0.4324 - val_accuracy: 0.8438 - val_precision: 0.8438 - val_recall: 0.8438 - val_auc: 0.8994 - val_f1_Score: 0.7823 - lr: 3.1623e-04 - 43s/epoch - 3s/step
# Epoch 13/30
# 15/15 - 50s - loss: 0.3165 - accuracy: 0.8750 - precision: 0.8750 - recall: 0.8750 - auc: 0.9384 - f1_Score: 0.8744 - val_loss: 0.7383 - val_accuracy: 0.5625 - val_precision: 0.5625 - val_recall: 0.5625 - val_auc: 0.8066 - val_f1_Score: 0.3600 - lr: 3.1623e-04 - 50s/epoch - 3s/step
# Epoch 14/30
# 15/15 - 40s - loss: 0.2506 - accuracy: 0.9125 - precision: 0.9125 - recall: 0.9125 - auc: 0.9637 - f1_Score: 0.9122 - val_loss: 0.3673 - val_accuracy: 0.8750 - val_precision: 0.8750 - val_recall: 0.8750 - val_auc: 0.9219 - val_f1_Score: 0.8545 - lr: 3.1623e-04 - 40s/epoch - 3s/step
# Epoch 15/30
# 15/15 - 41s - loss: 0.2662 - accuracy: 0.8750 - precision: 0.8750 - recall: 0.8750 - auc: 0.9571 - f1_Score: 0.8750 - val_loss: 0.1197 - val_accuracy: 0.9688 - val_precision: 0.9688 - val_recall: 0.9688 - val_auc: 0.9971 - val_f1_Score: 0.9680 - lr: 1.0000e-04 - 41s/epoch - 3s/step
# Epoch 16/30
# 15/15 - 37s - loss: 0.2555 - accuracy: 0.9042 - precision: 0.9042 - recall: 0.9042 - auc: 0.9584 - f1_Score: 0.9042 - val_loss: 0.6257 - val_accuracy: 0.6875 - val_precision: 0.6875 - val_recall: 0.6875 - val_auc: 0.8643 - val_f1_Score: 0.6364 - lr: 1.0000e-04 - 37s/epoch - 2s/step
# Epoch 17/30
# 15/15 - 40s - loss: 0.3142 - accuracy: 0.8708 - precision: 0.8708 - recall: 0.8708 - auc: 0.9409 - f1_Score: 0.8708 - val_loss: 0.2291 - val_accuracy: 0.9062 - val_precision: 0.9062 - val_recall: 0.9062 - val_auc: 0.9717 - val_f1_Score: 0.9039 - lr: 1.0000e-04 - 40s/epoch - 3s/step
# Epoch 18/30
# 15/15 - 33s - loss: 0.2282 - accuracy: 0.9042 - precision: 0.9042 - recall: 0.9042 - auc: 0.9688 - f1_Score: 0.9042 - val_loss: 0.1304 - val_accuracy: 0.9375 - val_precision: 0.9375 - val_recall: 0.9375 - val_auc: 0.9941 - val_f1_Score: 0.9352 - lr: 1.0000e-04 - 33s/epoch - 2s/step
# Epoch 19/30
# 15/15 - 31s - loss: 0.2704 - accuracy: 0.8958 - precision: 0.8958 - recall: 0.8958 - auc: 0.9542 - f1_Score: 0.8957 - val_loss: 0.0826 - val_accuracy: 0.9688 - val_precision: 0.9688 - val_recall: 0.9688 - val_auc: 0.9990 - val_f1_Score: 0.9680 - lr: 1.0000e-04 - 31s/epoch - 2s/step
# Epoch 20/30
# 15/15 - 31s - loss: 0.2704 - accuracy: 0.8933 - precision: 0.8933 - recall: 0.8933 - auc: 0.9544 - f1_Score: 0.8933 - val_loss: 0.1380 - val_accuracy: 0.9062 - val_precision: 0.9062 - val_recall: 0.9062 - val_auc: 0.9912 - val_f1_Score: 0.8982 - lr: 1.0000e-04 - 31s/epoch - 2s/step
# Epoch 21/30
# 15/15 - 31s - loss: 0.2381 - accuracy: 0.9167 - precision: 0.9167 - recall: 0.9167 - auc: 0.9666 - f1_Score: 0.9166 - val_loss: 0.1946 - val_accuracy: 0.9375 - val_precision: 0.9375 - val_recall: 0.9375 - val_auc: 0.9785 - val_f1_Score: 0.9333 - lr: 1.0000e-04 - 31s/epoch - 2s/step
# Epoch 22/30
# 15/15 - 28s - loss: 0.2232 - accuracy: 0.8958 - precision: 0.8958 - recall: 0.8958 - auc: 0.9696 - f1_Score: 0.8957 - val_loss: 0.2612 - val_accuracy: 0.8438 - val_precision: 0.8438 - val_recall: 0.8438 - val_auc: 0.9697 - val_f1_Score: 0.8424 - lr: 1.0000e-04 - 28s/epoch - 2s/step
# Epoch 23/30
# 15/15 - 25s - loss: 0.2617 - accuracy: 0.9000 - precision: 0.9000 - recall: 0.9000 - auc: 0.9584 - f1_Score: 0.8996 - val_loss: 0.0434 - val_accuracy: 0.9688 - val_precision: 0.9688 - val_recall: 0.9688 - val_auc: 0.9990 - val_f1_Score: 0.9687 - lr: 1.0000e-04 - 25s/epoch - 2s/step
# Epoch 24/30
# 15/15 - 24s - loss: 0.2020 - accuracy: 0.9042 - precision: 0.9042 - recall: 0.9042 - auc: 0.9760 - f1_Score: 0.9042 - val_loss: 0.1557 - val_accuracy: 0.9375 - val_precision: 0.9375 - val_recall: 0.9375 - val_auc: 0.9902 - val_f1_Score: 0.9365 - lr: 1.0000e-04 - 24s/epoch - 2s/step
# Epoch 25/30
# 15/15 - 26s - loss: 0.2315 - accuracy: 0.9125 - precision: 0.9125 - recall: 0.9125 - auc: 0.9682 - f1_Score: 0.9124 - val_loss: 0.0815 - val_accuracy: 0.9688 - val_precision: 0.9688 - val_recall: 0.9688 - val_auc: 0.9990 - val_f1_Score: 0.9646 - lr: 1.0000e-04 - 26s/epoch - 2s/step
# Epoch 26/30
# 15/15 - 26s - loss: 0.1475 - accuracy: 0.9625 - precision: 0.9625 - recall: 0.9625 - auc: 0.9889 - f1_Score: 0.9625 - val_loss: 0.1321 - val_accuracy: 0.9375 - val_precision: 0.9375 - val_recall: 0.9375 - val_auc: 0.9922 - val_f1_Score: 0.9373 - lr: 1.0000e-04 - 26s/epoch - 2s/step
# Epoch 27/30
# 15/15 - 28s - loss: 0.1519 - accuracy: 0.9333 - precision: 0.9333 - recall: 0.9333 - auc: 0.9872 - f1_Score: 0.9330 - val_loss: 0.3542 - val_accuracy: 0.8438 - val_precision: 0.8438 - val_recall: 0.8438 - val_auc: 0.9258 - val_f1_Score: 0.8424 - lr: 1.0000e-04 - 28s/epoch - 2s/step
# Epoch 28/30
# 15/15 - 25s - loss: 0.2623 - accuracy: 0.8833 - precision: 0.8833 - recall: 0.8833 - auc: 0.9593 - f1_Score: 0.8833 - val_loss: 0.1350 - val_accuracy: 0.9062 - val_precision: 0.9062 - val_recall: 0.9062 - val_auc: 0.9912 - val_f1_Score: 0.9054 - lr: 1.0000e-04 - 25s/epoch - 2s/step
# Epoch 29/30
# 15/15 - 19s - loss: 0.1759 - accuracy: 0.9333 - precision: 0.9333 - recall: 0.9333 - auc: 0.9808 - f1_Score: 0.9332 - val_loss: 0.0403 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000 - val_f1_Score: 1.0000 - lr: 3.1623e-05 - 19s/epoch - 1s/step
# Epoch 30/30
# 15/15 - 23s - loss: 0.1874 - accuracy: 0.9208 - precision: 0.9208 - recall: 0.9208 - auc: 0.9782 - f1_Score: 0.9206 - val_loss: 0.3101 - val_accuracy: 0.8438 - val_precision: 0.8438 - val_recall: 0.8438 - val_auc: 0.9629 - val_f1_Score: 0.8398 - lr: 3.1623e-05 - 23s/epoch - 2s/step

# %% [markdown]
# ## **5. Plotting the Model Metrics**
# ### i. Plotting training and validation accuracy, loss and learning rate

# %%
plt.figure( figsize = (15,8)) 
    
plt.subplot(221)  
# Accuracy 
plt.plot(model.history.history['accuracy'])
plt.plot(model.history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Training set', 'Validation set'], loc='upper left')
plt.show()


# Loss
plt.figure( figsize = (15,8)) 
plt.subplot(222)  
plt.plot(model.history.history['loss'])
plt.plot(model.history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Training set', 'Validation set'], loc='upper left')
plt.show()

# %%
train_accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

train_loss = history.history['loss']
val_loss = history.history['val_loss']

learning_rate = history.history['lr']
# ans = history.history['val_auc']
# ans

# %%
train_accuracy
# Out:
# [0.6583333611488342,
#  0.6416666507720947,
#  0.75,
#  0.8583333492279053,
#  0.7916666865348816,
#  0.7777777910232544,
#  0.7416666746139526,
#  0.7749999761581421,
#  0.800000011920929,
#  0.8500000238418579,
#  0.875,
#  0.8708333373069763,
#  0.875,
#  0.9125000238418579,
#  0.875,
#  0.9041666388511658,
#  0.8708333373069763,
#  0.9041666388511658,
#  0.8958333134651184,
#  0.8933333158493042,
#  0.9166666865348816,
#  0.8958333134651184,
#  0.8999999761581421,
#  0.9041666388511658,
#  0.9125000238418579,
#  0.9624999761581421,
#  0.9333333373069763,
#  0.8833333253860474,
#  0.9333333373069763,
#  0.9208333492279053]

# %%
fig, ax = plt.subplots(nrows=3, ncols=1, figsize=(12, 10))

ax[0].set_title('Training Accuracy vs. Epochs')
ax[0].plot(train_accuracy, 'o-', label='Train Accuracy')
ax[0].plot(val_accuracy, 'o-', label='Validation Accuracy')
ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Accuracy')
ax[0].legend(loc='best')

ax[1].set_title('Training/Validation Loss vs. Epochs')
ax[1].plot(train_loss, 'o-', label='Train Loss')
ax[1].plot(val_loss, 'o-', label='Validation Loss')
ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Loss')
ax[1].legend(loc='best')

ax[2].set_title('Learning Rate vs. Epochs')
ax[2].plot(learning_rate, 'o-', label='Learning Rate')
ax[2].set_xlabel('Epochs')
ax[2].set_ylabel('Loss')
ax[2].legend(loc='best')

plt.tight_layout()
plt.show()

# %%
def Train_Val_Plot(acc,val_acc,loss,val_loss,auc,val_auc,precision,val_precision,f1_Score,val_f1_Score):
    
    fig, (ax1, ax2,ax3,ax4,ax5) = plt.subplots(1,5, figsize= (20,5))
    fig.suptitle(" MODEL'S METRICS VISUALIZATION ")

    ax1.plot(range(1, len(acc) + 1), acc)
    ax1.plot(range(1, len(val_acc) + 1), val_acc)
    ax1.set_title('History of Accuracy')
    ax1.set_xlabel('Epochs')
    ax1.set_ylabel('Accuracy')
    ax1.legend(['training', 'validation'])


    ax2.plot(range(1, len(loss) + 1), loss)
    ax2.plot(range(1, len(val_loss) + 1), val_loss)
    ax2.set_title('History of Loss')
    ax2.set_xlabel('Epochs')
    ax2.set_ylabel('Loss')
    ax2.legend(['training', 'validation'])
    
    ax3.plot(range(1, len(auc) + 1), auc)
    ax3.plot(range(1, len(val_auc) + 1), val_auc)
    ax3.set_title('History of AUC')
    ax3.set_xlabel('Epochs')
    ax3.set_ylabel('AUC')
    ax3.legend(['training', 'validation'])
    
    ax4.plot(range(1, len(precision) + 1), precision)
    ax4.plot(range(1, len(val_precision) + 1), val_precision)
    ax4.set_title('History of Precision')
    ax4.set_xlabel('Epochs')
    ax4.set_ylabel('Precision')
    ax4.legend(['training', 'validation'])
    
    ax5.plot(range(1, len(f1_Score) + 1), f1_Score)
    ax5.plot(range(1, len(val_f1_Score) + 1), val_f1_Score)
    ax5.set_title('History of F1-score')
    ax5.set_xlabel('Epochs')
    ax5.set_ylabel('F1 score')
    ax5.legend(['training', 'validation'])


    plt.show()
    
import numpy as np
# f1_s= np.mean(history.history['f1_Score'])
# val_f1_s= np.mean(history.history['val_f1_Score'])
Train_Val_Plot(history.history['accuracy'],history.history['val_accuracy'],
               history.history['loss'],history.history['val_loss'],
               history.history['auc'],history.history['val_auc'],
               history.history['precision'],history.history['val_precision']
              #  f1_s,val_f1_s

                , history.history['f1_Score'],history.history['val_f1_Score']
              )

# %% [markdown]
# ## 6. Testing the Model on Test Set
# Testing the model on the validation dataset because a seperate dataset for testing is not available.

# %%
test_dataset = '/content/drive/MyDrive/FYP/test'

# %%
test_datagen = ImageDataGenerator(rescale=1.0/255)

test_generator = test_datagen.flow_from_directory(test_dataset,
                                                 shuffle=False,
                                                 batch_size=BATCH_SIZE,
                                                 target_size = (IMG_WIDTH, IMG_HEIGHT),
                                                 class_mode='categorical')
# Out:
# Found 3000 images belonging to 2 classes.

# %% [markdown]
# ## 7. Model Prediction on the Test Dataset

# %%
predictions = model.predict(test_generator)
# Out:
# 188/188 [==============================] - 682s 4s/step

# %%
fig, ax = plt.subplots(nrows=2, ncols=5, figsize=(12, 10))
idx = 0

for i in range(2):
    for j in range(5):
        predicted_label = labels[np.argmax(predictions[idx])]
        ax[i, j].set_title(f"{predicted_label}")
        ax[i, j].imshow(test_generator[0][0][idx])
        ax[i, j].axis("off")
        idx += 1

plt.tight_layout()
plt.suptitle("Test Dataset Predictions", fontsize=20)
plt.show()

# %%
train_loss, train_accuracy, train_precision, train_recall, train_auc, train_F1_Score = model.evaluate(train_generator, batch_size=BATCH_SIZE)
# Out:
# 189/189 [==============================] - 95s 505ms/step - loss: 0.1394 - accuracy: 0.9402 - precision: 0.9402 - recall: 0.9402 - auc: 0.9884 - f1_Score: 0.9401

# %%
print(f"Train Loss:     {train_loss}")
print(f"Train Accuracy: {train_accuracy}")
print(f"Train Precision: {train_precision}")
print(f"Train Recall: {train_recall}")
print(f"Train AUC: {train_auc}")
print(f"Train F1_Score: {np.mean(train_F1_Score)}")
# Out:
# Train Loss:     0.13942879438400269
# Train Accuracy: 0.9401794672012329
# Train Precision: 0.9401794672012329
# Train Recall: 0.9401794672012329
# Train AUC: 0.988442063331604
# Train F1_Score: 0.9401092529296875

# %%
test_loss, test_accuracy, test_precision, test_recall, test_auc, test_F1_Score = model.evaluate(test_generator, batch_size=BATCH_SIZE)
# Out:
# 188/188 [==============================] - 39s 205ms/step - loss: 0.2446 - accuracy: 0.8787 - precision: 0.8787 - recall: 0.8787 - auc: 0.9678 - f1_Score: 0.8770

# %%
print(f"Test Loss:     {test_loss}")
print(f"Test Accuracy: {test_accuracy}")
print(f"Test Precision: {test_precision}")
print(f"Test Recall: {test_recall}")
print(f"Test AUC: {test_auc}")
print(f"Test F1_Score: {np.mean(test_F1_Score)}")
# Out:
# Test Loss:     0.24459108710289001
# Test Accuracy: 0.8786666393280029
# Test Precision: 0.8786666393280029
# Test Recall: 0.8786666393280029
# Test AUC: 0.9678441882133484
# Test F1_Score: 0.8769924640655518

# %% [markdown]
# ## **8. Plotting the Classification Metrics**
# ### i. Confusion Matrix

# %%
y_pred = np.argmax(predictions, axis=1)
y_true = test_generator.classes

# %%
cf_mtx = confusion_matrix(y_true, y_pred)

group_counts = ["{0:0.0f}".format(value) for value in cf_mtx.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in cf_mtx.flatten()/np.sum(cf_mtx)]
box_labels = [f"{v1}\n({v2})" for v1, v2 in zip(group_counts, group_percentages)]
box_labels = np.asarray(box_labels).reshape(2, 2)

plt.figure(figsize = (12, 10))
sns.heatmap(cf_mtx, xticklabels=labels.values(), yticklabels=labels.values(),
           cmap="YlGnBu", fmt="", annot=box_labels)
plt.xlabel('Predicted Classes')
plt.ylabel('True Classes')
plt.show()

# %%
print(classification_report(y_true, y_pred, target_names=labels.values()))
# Out:
#               precision    recall  f1-score   support
#
#      Nonnude       0.99      0.76      0.86      1500
#         Nude       0.81      1.00      0.89      1500
#
#     accuracy                           0.88      3000
#    macro avg       0.90      0.88      0.88      3000
# weighted avg       0.90      0.88      0.88      3000

# %%
A=history.history['accuracy']
A_v=history.history['val_accuracy']
L=history.history['loss']
L_v=history.history['val_loss']
Auc=history.history['auc']
Auc_v=history.history['val_auc']
P=history.history['precision']
P_v=history.history['val_precision']
F1=history.history['f1_Score']
F1_v=history.history['val_f1_Score']

# %%
import pandas as pd
data_to_submit = pd.DataFrame({
    'accuracy':A,
    'val_accuracy':A_v,
    'loss': L,
    'val_loss': L_v,
    'auc':Auc,
    'val_auc':Auc_v,
    'precision':P,
    'val_precision':P_v,
    'f1_score':F1,
    'val_f1_score':F1_v
})
data_to_submit.to_csv('csv_to_submit.csv', index = False)
